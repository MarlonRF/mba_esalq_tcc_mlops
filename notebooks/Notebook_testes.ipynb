# %% [markdown]
# # 🧪 Executar Testes do Projeto
#
# Este notebook permite executar todos os testes do projeto MLOps de forma interativa.
#
# ## Estrutura de Testes
#
# - **Testes Unitários** (`tests/unit/`): Testes rápidos e isolados (55 arquivos)
# - **Testes de Integração** (`tests/integration/`): Testes end-to-end (7 arquivos)
# - **Total**: 62 arquivos de teste
# - **Cobertura**: ~85%

# %% [markdown]
# ## 📦 Setup - Imports e Configuração

# %%
import sys
import subprocess
from pathlib import Path

# Define o diretório raiz do projeto
PROJECT_ROOT = Path.cwd().parent
sys.path.insert(0, str(PROJECT_ROOT))

print(f"📁 Diretório do projeto: {PROJECT_ROOT}")
print(f"📂 Diretório de testes: {PROJECT_ROOT / 'tests'}")
# Out:
# 📁 Diretório do projeto: c:\Arquivos_Pessoais\PROJETOS
# 📂 Diretório de testes: c:\Arquivos_Pessoais\PROJETOS\tests

# %% [markdown]
# ## 🚀 Executar Todos os Testes
#
# Executa todos os testes (unitários + integração).

# %%
# %%time
# Executa todos os testes
tests_path = str(PROJECT_ROOT / 'tests')
# !python -m pytest "{tests_path}" -v --tb=short
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.0, pytest-7.4.3, pluggy-1.6.0 -- c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\.venv\Scripts\python.exe
# cachedir: .pytest_cache
# hypothesis profile 'default' -> database=DirectoryBasedExampleDatabase(WindowsPath('c:/Arquivos_Pessoais/PROJETOS/tcc_mba_esalq_mlops/.hypothesis/examples'))
# rootdir: c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops
# configfile: pytest.ini
# plugins: anyio-4.12.1, dash-4.0.0, Faker-20.1.0, hypothesis-6.99.13, asyncio-0.21.1, cov-4.1.0, mock-3.12.0, timeout-2.4.0
# asyncio: mode=Mode.STRICT
# collecting ... collected 0 items
#
# ============================ no tests ran in 0.24s ============================
# CPU times: total: 0 ns
# Wall time: 3.14 s
# ERROR: file or directory not found: c:\Arquivos_Pessoais\PROJETOS\tests

# %% [markdown]
# ## ⚡ Executar Apenas Testes Unitários (Rápido)
#
# Testes unitários são rápidos (~1-2 minutos) e testam funções isoladas.

# %%
# %%time
# Executa apenas testes unitários
tests_path = str(PROJECT_ROOT / 'tests' / 'unit')
# !python -m pytest "{tests_path}" -v --tb=short
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.0, pytest-7.4.3, pluggy-1.6.0 -- c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\.venv\Scripts\python.exe
# cachedir: .pytest_cache
# hypothesis profile 'default' -> database=DirectoryBasedExampleDatabase(WindowsPath('c:/Arquivos_Pessoais/PROJETOS/tcc_mba_esalq_mlops/.hypothesis/examples'))
# rootdir: c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops
# configfile: pytest.ini
# plugins: anyio-4.12.1, dash-4.0.0, Faker-20.1.0, hypothesis-6.99.13, asyncio-0.21.1, cov-4.1.0, mock-3.12.0, timeout-2.4.0
# asyncio: mode=Mode.STRICT
# collecting ... collected 223 items / 11 errors
#
# =================================== ERRORS ====================================
# ____________ ERROR collecting tests/unit/test_features_criacao.py _____________
# .venv\Lib\site-packages\_pytest\python.py:617: in _importtestmodule
#     mod = import_path(self.path, mode=importmode, root=self.config.rootpath)
# .venv\Lib\site-packages\_pytest\pathlib.py:567: in import_path
#     importlib.import_module(module_name)
# C:\Python311\Lib\importlib\__init__.py:126: in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
# <frozen importlib._bootstrap>:1206: in _gcd_import
#     ???
# <frozen importlib._bootstrap>:1178: in _find_and_load
#     ???
# <frozen importlib._bootstrap>:1149: in _find_and_load_unlocked
#     ???
# <frozen importlib._bootstrap>:690: in _load_unlocked
#     ???
# .venv\Lib\site-packages\_pytest\assertion\rewrite.py:177: in exec_module
#     source_stat, co = _rewrite_test(fn, self.config)
# .venv\Lib\site-packages\_pytest\assertion\rewrite.py:359: in _rewrite_test
#     tree = ast.parse(source, filename=strfn)
# C:\Python311\Lib\ast.py:50: in parse
#     return compile(source, filename, mode, flags,
# E     File "c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\tests\unit\test_features_criacao.py", line 12
# E       <<<<<<< Updated upstream
# E       ^^
# E   SyntaxError: invalid syntax
# ___ ERROR collecting tests/unit/features/codificacao/test_aplicar_dummy.py ____
# ImportError while importing test module 'c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\tests\unit\features\codificacao\test_aplicar_dummy.py'.
# Hint: make sure your test modules/packages have valid Python names.
# Traceback:
# .venv\Lib\site-packages\_pytest\python.py:617: in _importtestmodule
#     mod = import_path(self.path, mode=importmode, root=self.config.rootpath)
# .venv\Lib\site-packages\_pytest\pathlib.py:567: in import_path
#     importlib.import_module(module_name)
# C:\Python311\Lib\importlib\__init__.py:126: in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
# <frozen importlib._bootstrap>:1206: in _gcd_import
#     ???
# <frozen importlib._bootstrap>:1178: in _find_and_load
#     ???
# <frozen importlib._bootstrap>:1149: in _find_and_load_unlocked
#     ???
# <frozen importlib._bootstrap>:690: in _load_unlocked
#     ???
# .venv\Lib\site-packages\_pytest\assertion\rewrite.py:186: in exec_module
#     exec(co, module.__dict__)
# tests\unit\features\codificacao\test_aplicar_dummy.py:6: in <module>
#     from src.features.codificacao.aplicar_dummy import aplicar_dummy_encoding
# E   ImportError: cannot import name 'aplicar_dummy_encoding' from 'src.features.codificacao.aplicar_dummy' (c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\features\codificacao\aplicar_dummy.py)
# _ ERROR collecting tests/unit/features/criacao_features/test_calcular_tu_stull.py _
# ImportError while importing test module 'c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\tests\unit\features\criacao_features\test_calcular_tu_stull.py'.
# Hint: make sure your test modules/packages have valid Python names.
# Traceback:
# .venv\Lib\site-packages\_pytest\python.py:617: in _importtestmodule
#     mod = import_path(self.path, mode=importmode, root=self.config.rootpath)
# .venv\Lib\site-packages\_pytest\pathlib.py:567: in import_path
#     importlib.import_module(module_name)
# C:\Python311\Lib\importlib\__init__.py:126: in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
# <frozen importlib._bootstrap>:1206: in _gcd_import
#     ???
# <frozen importlib._bootstrap>:1178: in _find_and_load
#     ???
# <frozen importlib._bootstrap>:1149: in _find_and_load_unlocked
#     ???
# <frozen importlib._bootstrap>:690: in _load_unlocked
#     ???
# .venv\Lib\site-packages\_pytest\assertion\rewrite.py:186: in exec_module
#     exec(co, module.__dict__)
# tests\unit\features\criacao_features\test_calcular_tu_stull.py:5: in <module>
#     from src.processamento.derivadas.calcular_tu_stull import calcular_tu_stull
# E   ModuleNotFoundError: No module named 'src.processamento.derivadas'
# __ ERROR collecting tests/unit/features/normalizacao/test_definir_escalar.py __
# ImportError while importing test module 'c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\tests\unit\features\normalizacao\test_definir_escalar.py'.
# Hint: make sure your test modules/packages have valid Python names.
# Traceback:
# .venv\Lib\site-packages\_pytest\python.py:617: in _importtestmodule
#     mod = import_path(self.path, mode=importmode, root=self.config.rootpath)
# .venv\Lib\site-packages\_pytest\pathlib.py:567: in import_path
#     importlib.import_module(module_name)
# C:\Python311\Lib\importlib\__init__.py:126: in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
# <frozen importlib._bootstrap>:1206: in _gcd_import
#     ???
# <frozen importlib._bootstrap>:1178: in _find_and_load
#     ???
# <frozen importlib._bootstrap>:1149: in _find_and_load_unlocked
#     ???
# <frozen importlib._bootstrap>:690: in _load_unlocked
#     ???
# .venv\Lib\site-packages\_pytest\assertion\rewrite.py:186: in exec_module
#     exec(co, module.__dict__)
# tests\unit\features\normalizacao\test_definir_escalar.py:4: in <module>
#     from src.processamento.normalizacao.pick_scaler import pick_scaler
# E   ModuleNotFoundError: No module named 'src.processamento.normalizacao'
# ____ ERROR collecting tests/unit/features/normalizacao/test_normalizar.py _____
# ImportError while importing test module 'c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\tests\unit\features\normalizacao\test_normalizar.py'.
# Hint: make sure your test modules/packages have valid Python names.
# Traceback:
# .venv\Lib\site-packages\_pytest\python.py:617: in _importtestmodule
#     mod = import_path(self.path, mode=importmode, root=self.config.rootpath)
# .venv\Lib\site-packages\_pytest\pathlib.py:567: in import_path
#     importlib.import_module(module_name)
# C:\Python311\Lib\importlib\__init__.py:126: in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
# <frozen importlib._bootstrap>:1206: in _gcd_import
#     ???
# <frozen importlib._bootstrap>:1178: in _find_and_load
#     ???
# <frozen importlib._bootstrap>:1149: in _find_and_load_unlocked
#     ???
# <frozen importlib._bootstrap>:690: in _load_unlocked
#     ???
# .venv\Lib\site-packages\_pytest\assertion\rewrite.py:186: in exec_module
#     exec(co, module.__dict__)
# tests\unit\features\normalizacao\test_normalizar.py:5: in <module>
#     from src.processamento.normalizacao.normalizar import normalizar
# E   ModuleNotFoundError: No module named 'src.processamento.normalizacao'
# _______ ERROR collecting tests/unit/processamento/test_limpeza_geral.py _______
# .venv\Lib\site-packages\_pytest\python.py:617: in _importtestmodule
#     mod = import_path(self.path, mode=importmode, root=self.config.rootpath)
# .venv\Lib\site-packages\_pytest\pathlib.py:567: in import_path
#     importlib.import_module(module_name)
# C:\Python311\Lib\importlib\__init__.py:126: in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
# <frozen importlib._bootstrap>:1206: in _gcd_import
#     ???
# <frozen importlib._bootstrap>:1178: in _find_and_load
#     ???
# <frozen importlib._bootstrap>:1149: in _find_and_load_unlocked
#     ???
# <frozen importlib._bootstrap>:690: in _load_unlocked
#     ???
# .venv\Lib\site-packages\_pytest\assertion\rewrite.py:177: in exec_module
#     source_stat, co = _rewrite_test(fn, self.config)
# .venv\Lib\site-packages\_pytest\assertion\rewrite.py:359: in _rewrite_test
#     tree = ast.parse(source, filename=strfn)
# C:\Python311\Lib\ast.py:50: in parse
#     return compile(source, filename, mode, flags,
# E     File "c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\tests\unit\processamento\test_limpeza_geral.py", line 43
# E       )
# E       ^
# E   SyntaxError: unmatched ')'
# _________ ERROR collecting tests/unit/processamento/test_temporal.py __________
# ImportError while importing test module 'c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\tests\unit\processamento\test_temporal.py'.
# Hint: make sure your test modules/packages have valid Python names.
# Traceback:
# .venv\Lib\site-packages\_pytest\python.py:617: in _importtestmodule
#     mod = import_path(self.path, mode=importmode, root=self.config.rootpath)
# .venv\Lib\site-packages\_pytest\pathlib.py:567: in import_path
#     importlib.import_module(module_name)
# C:\Python311\Lib\importlib\__init__.py:126: in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
# <frozen importlib._bootstrap>:1206: in _gcd_import
#     ???
# <frozen importlib._bootstrap>:1178: in _find_and_load
#     ???
# <frozen importlib._bootstrap>:1149: in _find_and_load_unlocked
#     ???
# <frozen importlib._bootstrap>:690: in _load_unlocked
#     ???
# .venv\Lib\site-packages\_pytest\assertion\rewrite.py:186: in exec_module
#     exec(co, module.__dict__)
# tests\unit\processamento\test_temporal.py:8: in <module>
#     from src.processamento.temporal import (
# E   ImportError: cannot import name 'criar_coluna_temporal' from 'src.processamento.temporal' (c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\processamento\temporal\__init__.py)
# ___________ ERROR collecting tests/unit/processamento/test_utils.py ___________
# ImportError while importing test module 'c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\tests\unit\processamento\test_utils.py'.
# Hint: make sure your test modules/packages have valid Python names.
# Traceback:
# .venv\Lib\site-packages\_pytest\python.py:617: in _importtestmodule
#     mod = import_path(self.path, mode=importmode, root=self.config.rootpath)
# .venv\Lib\site-packages\_pytest\pathlib.py:567: in import_path
#     importlib.import_module(module_name)
# C:\Python311\Lib\importlib\__init__.py:126: in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
# <frozen importlib._bootstrap>:1206: in _gcd_import
#     ???
# <frozen importlib._bootstrap>:1178: in _find_and_load
#     ???
# <frozen importlib._bootstrap>:1149: in _find_and_load_unlocked
#     ???
# <frozen importlib._bootstrap>:690: in _load_unlocked
#     ???
# .venv\Lib\site-packages\_pytest\assertion\rewrite.py:186: in exec_module
#     exec(co, module.__dict__)
# tests\unit\processamento\test_utils.py:12: in <module>
#     from funcoes.processamento import (_calcular_imc, _calcular_indice_calor,
# E   ModuleNotFoundError: No module named 'funcoes'
# __ ERROR collecting tests/unit/treinamento/avaliacao/test_avaliar_modelo.py ___
# ImportError while importing test module 'c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\tests\unit\treinamento\avaliacao\test_avaliar_modelo.py'.
# Hint: make sure your test modules/packages have valid Python names.
# Traceback:
# .venv\Lib\site-packages\_pytest\python.py:617: in _importtestmodule
#     mod = import_path(self.path, mode=importmode, root=self.config.rootpath)
# .venv\Lib\site-packages\_pytest\pathlib.py:567: in import_path
#     importlib.import_module(module_name)
# C:\Python311\Lib\importlib\__init__.py:126: in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
# <frozen importlib._bootstrap>:1206: in _gcd_import
#     ???
# <frozen importlib._bootstrap>:1178: in _find_and_load
#     ???
# <frozen importlib._bootstrap>:1149: in _find_and_load_unlocked
#     ???
# <frozen importlib._bootstrap>:690: in _load_unlocked
#     ???
# .venv\Lib\site-packages\_pytest\assertion\rewrite.py:186: in exec_module
#     exec(co, module.__dict__)
# tests\unit\treinamento\avaliacao\test_avaliar_modelo.py:10: in <module>
#     from src.treinamento.avaliar_modelo import avaliar_modelo
# E   ModuleNotFoundError: No module named 'src.treinamento.avaliar_modelo'
# __ ERROR collecting tests/unit/treinamento/avaliacao/test_fazer_predicoes.py __
# ImportError while importing test module 'c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\tests\unit\treinamento\avaliacao\test_fazer_predicoes.py'.
# Hint: make sure your test modules/packages have valid Python names.
# Traceback:
# .venv\Lib\site-packages\_pytest\python.py:617: in _importtestmodule
#     mod = import_path(self.path, mode=importmode, root=self.config.rootpath)
# .venv\Lib\site-packages\_pytest\pathlib.py:567: in import_path
#     importlib.import_module(module_name)
# C:\Python311\Lib\importlib\__init__.py:126: in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
# <frozen importlib._bootstrap>:1206: in _gcd_import
#     ???
# <frozen importlib._bootstrap>:1178: in _find_and_load
#     ???
# <frozen importlib._bootstrap>:1149: in _find_and_load_unlocked
#     ???
# <frozen importlib._bootstrap>:690: in _load_unlocked
#     ???
# .venv\Lib\site-packages\_pytest\assertion\rewrite.py:186: in exec_module
#     exec(co, module.__dict__)
# tests\unit\treinamento\avaliacao\test_fazer_predicoes.py:9: in <module>
#     from src.treinamento.fazer_predicoes import fazer_predicoes
# E   ModuleNotFoundError: No module named 'src.treinamento.fazer_predicoes'
# _ ERROR collecting tests/unit/treinamento/treino/test_treinar_modelo_base.py __
# ImportError while importing test module 'c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\tests\unit\treinamento\treino\test_treinar_modelo_base.py'.
# Hint: make sure your test modules/packages have valid Python names.
# Traceback:
# .venv\Lib\site-packages\_pytest\python.py:617: in _importtestmodule
#     mod = import_path(self.path, mode=importmode, root=self.config.rootpath)
# .venv\Lib\site-packages\_pytest\pathlib.py:567: in import_path
#     importlib.import_module(module_name)
# C:\Python311\Lib\importlib\__init__.py:126: in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
# <frozen importlib._bootstrap>:1206: in _gcd_import
#     ???
# <frozen importlib._bootstrap>:1178: in _find_and_load
#     ???
# <frozen importlib._bootstrap>:1149: in _find_and_load_unlocked
#     ???
# <frozen importlib._bootstrap>:690: in _load_unlocked
#     ???
# .venv\Lib\site-packages\_pytest\assertion\rewrite.py:186: in exec_module
#     exec(co, module.__dict__)
# tests\unit\treinamento\treino\test_treinar_modelo_base.py:10: in <module>
#     from src.treinamento.treinar_modelo_base import treinar_modelo_base
# E   ModuleNotFoundError: No module named 'src.treinamento.treinar_modelo_base'
#
# ---------- coverage: platform win32, python 3.11.0-final-0 -----------
# Name                         Stmts   Miss  Cover   Missing
# ----------------------------------------------------------
# tests\unit\api\__init__.py       0      0   100%
# tests\unit\api\test_app.py      58     38    34%   20-35, 40-45, 50-68, 74-81, 86-101, 106-117, 122-123, 129-130
# ----------------------------------------------------------
# TOTAL                           58     38    34%
# Coverage HTML written to dir htmlcov
# Coverage XML written to file coverage.xml
#
# =========================== short test summary info ===========================
# ERROR tests/unit/test_features_criacao.py
# ERROR tests/unit/features/codificacao/test_aplicar_dummy.py
# ERROR tests/unit/features/criacao_features/test_calcular_tu_stull.py
# ERROR tests/unit/features/normalizacao/test_definir_escalar.py
# ERROR tests/unit/features/normalizacao/test_normalizar.py
# ERROR tests/unit/processamento/test_limpeza_geral.py
# ERROR tests/unit/processamento/test_temporal.py
# ERROR tests/unit/processamento/test_utils.py
# ERROR tests/unit/treinamento/avaliacao/test_avaliar_modelo.py
# ERROR tests/unit/treinamento/avaliacao/test_fazer_predicoes.py
# ERROR tests/unit/treinamento/treino/test_treinar_modelo_base.py
# !!!!!!!!!!!!!!!!!! Interrupted: 11 errors during collection !!!!!!!!!!!!!!!!!!!
# ============================= 11 errors in 8.55s ==============================
# CPU times: total: 0 ns
# Wall time: 11.6 s
# c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\.venv\Lib\site-packages\coverage\inorout.py:497: CoverageWarning: Module funcoes was never imported. (module-not-imported); see https://coverage.readthedocs.io/en/7.13.1/messages.html#warning-module-not-imported
#   self.warn(f"Module {pkg} was never imported.", slug="module-not-imported")

# %% [markdown]
# ## 🔗 Executar Apenas Testes de Integração
#
# Testes de integração são mais lentos e testam fluxos completos end-to-end.

# %%
# %%time
# Executa apenas testes de integração
tests_path = str(PROJECT_ROOT / 'tests' / 'integration')
# !python -m pytest "{tests_path}" -v --tb=short
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.0, pytest-7.4.3, pluggy-1.6.0 -- c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\.venv\Scripts\python.exe
# cachedir: .pytest_cache
# hypothesis profile 'default' -> database=DirectoryBasedExampleDatabase(WindowsPath('c:/Arquivos_Pessoais/PROJETOS/tcc_mba_esalq_mlops/.hypothesis/examples'))
# rootdir: c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops
# configfile: pytest.ini
# plugins: anyio-4.12.1, dash-4.0.0, Faker-20.1.0, hypothesis-6.99.13, asyncio-0.21.1, cov-4.1.0, mock-3.12.0, timeout-2.4.0
# asyncio: mode=Mode.STRICT
# collecting ... collected 12 items / 4 errors
# WARNING: Failed to generate report: No data to report.
#
#
# =================================== ERRORS ====================================
# _________ ERROR collecting tests/integration/test_novos_pipelines.py __________
# ImportError while importing test module 'c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\tests\integration\test_novos_pipelines.py'.
# Hint: make sure your test modules/packages have valid Python names.
# Traceback:
# .venv\Lib\site-packages\_pytest\python.py:617: in _importtestmodule
#     mod = import_path(self.path, mode=importmode, root=self.config.rootpath)
# .venv\Lib\site-packages\_pytest\pathlib.py:567: in import_path
#     importlib.import_module(module_name)
# C:\Python311\Lib\importlib\__init__.py:126: in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
# <frozen importlib._bootstrap>:1206: in _gcd_import
#     ???
# <frozen importlib._bootstrap>:1178: in _find_and_load
#     ???
# <frozen importlib._bootstrap>:1149: in _find_and_load_unlocked
#     ???
# <frozen importlib._bootstrap>:690: in _load_unlocked
#     ???
# .venv\Lib\site-packages\_pytest\assertion\rewrite.py:186: in exec_module
#     exec(co, module.__dict__)
# tests\integration\test_novos_pipelines.py:18: in <module>
#     from src.config_projeto import config
# E   ModuleNotFoundError: No module named 'src.config_projeto'
# ______ ERROR collecting tests/integration/test_pipeline_processamento.py ______
# ImportError while importing test module 'c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\tests\integration\test_pipeline_processamento.py'.
# Hint: make sure your test modules/packages have valid Python names.
# Traceback:
# .venv\Lib\site-packages\_pytest\python.py:617: in _importtestmodule
#     mod = import_path(self.path, mode=importmode, root=self.config.rootpath)
# .venv\Lib\site-packages\_pytest\pathlib.py:567: in import_path
#     importlib.import_module(module_name)
# C:\Python311\Lib\importlib\__init__.py:126: in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
# <frozen importlib._bootstrap>:1206: in _gcd_import
#     ???
# <frozen importlib._bootstrap>:1178: in _find_and_load
#     ???
# <frozen importlib._bootstrap>:1149: in _find_and_load_unlocked
#     ???
# <frozen importlib._bootstrap>:690: in _load_unlocked
#     ???
# .venv\Lib\site-packages\_pytest\assertion\rewrite.py:186: in exec_module
#     exec(co, module.__dict__)
# tests\integration\test_pipeline_processamento.py:12: in <module>
#     from utils.processamento import ConfiguracaoProcessamento, processar_df
# E   ModuleNotFoundError: No module named 'utils.processamento'
# _ ERROR collecting tests/integration/test_pipeline_processamento_integration.py _
# ImportError while importing test module 'c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\tests\integration\test_pipeline_processamento_integration.py'.
# Hint: make sure your test modules/packages have valid Python names.
# Traceback:
# .venv\Lib\site-packages\_pytest\python.py:617: in _importtestmodule
#     mod = import_path(self.path, mode=importmode, root=self.config.rootpath)
# .venv\Lib\site-packages\_pytest\pathlib.py:567: in import_path
#     importlib.import_module(module_name)
# C:\Python311\Lib\importlib\__init__.py:126: in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
# <frozen importlib._bootstrap>:1206: in _gcd_import
#     ???
# <frozen importlib._bootstrap>:1178: in _find_and_load
#     ???
# <frozen importlib._bootstrap>:1149: in _find_and_load_unlocked
#     ???
# <frozen importlib._bootstrap>:690: in _load_unlocked
#     ???
# .venv\Lib\site-packages\_pytest\assertion\rewrite.py:186: in exec_module
#     exec(co, module.__dict__)
# tests\integration\test_pipeline_processamento_integration.py:12: in <module>
#     from config_projeto.config_processamento import PipelineConfig
# E   ModuleNotFoundError: No module named 'config_projeto'
# _______ ERROR collecting tests/integration/test_treinamento_pipeline.py _______
# ImportError while importing test module 'c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\tests\integration\test_treinamento_pipeline.py'.
# Hint: make sure your test modules/packages have valid Python names.
# Traceback:
# .venv\Lib\site-packages\_pytest\python.py:617: in _importtestmodule
#     mod = import_path(self.path, mode=importmode, root=self.config.rootpath)
# .venv\Lib\site-packages\_pytest\pathlib.py:567: in import_path
#     importlib.import_module(module_name)
# C:\Python311\Lib\importlib\__init__.py:126: in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
# <frozen importlib._bootstrap>:1206: in _gcd_import
#     ???
# <frozen importlib._bootstrap>:1178: in _find_and_load
#     ???
# <frozen importlib._bootstrap>:1149: in _find_and_load_unlocked
#     ???
# <frozen importlib._bootstrap>:690: in _load_unlocked
#     ???
# .venv\Lib\site-packages\_pytest\assertion\rewrite.py:186: in exec_module
#     exec(co, module.__dict__)
# tests\integration\test_treinamento_pipeline.py:10: in <module>
#     from src.treinamento import (
# E   ImportError: cannot import name 'treinar_rapido' from 'src.treinamento' (c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\treinamento\__init__.py)
#
# ---------- coverage: platform win32, python 3.11.0-final-0 -----------
#
# =========================== short test summary info ===========================
# ERROR tests/integration/test_novos_pipelines.py
# ERROR tests/integration/test_pipeline_processamento.py
# ERROR tests/integration/test_pipeline_processamento_integration.py
# ERROR tests/integration/test_treinamento_pipeline.py
# !!!!!!!!!!!!!!!!!!! Interrupted: 4 errors during collection !!!!!!!!!!!!!!!!!!!
# ======================== 4 errors in 71.99s (0:01:11) =========================
# CPU times: total: 15.6 ms
# Wall time: 1min 15s
# c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\.venv\Lib\site-packages\coverage\inorout.py:497: CoverageWarning: Module funcoes was never imported. (module-not-imported); see https://coverage.readthedocs.io/en/7.13.1/messages.html#warning-module-not-imported
#   self.warn(f"Module {pkg} was never imported.", slug="module-not-imported")
# c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\.venv\Lib\site-packages\coverage\inorout.py:497: CoverageWarning: Module api was never imported. (module-not-imported); see https://coverage.readthedocs.io/en/7.13.1/messages.html#warning-module-not-imported
#   self.warn(f"Module {pkg} was never imported.", slug="module-not-imported")
# c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\.venv\Lib\site-packages\coverage\control.py:958: CoverageWarning: No data was collected. (no-data-collected); see https://coverage.readthedocs.io/en/7.13.1/messages.html#warning-no-data-collected
#   self._warn("No data was collected.", slug="no-data-collected")
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq\.venv\Lib\site-packages\pytest_cov\plugin.py:312: CovReportWarning: Failed to generate report: No data to report.

# %% [markdown]
# ## 🎯 Executar Testes de Módulos Específicos
#
# ### Testes de Features

# %%
# Testa módulo de features (codificação, normalização, criação)
tests_path = str(PROJECT_ROOT / 'tests' / 'unit' / 'features')
# !python -m pytest "{tests_path}" -v
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.0, pytest-7.4.3, pluggy-1.6.0 -- c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\.venv\Scripts\python.exe
# cachedir: .pytest_cache
# hypothesis profile 'default' -> database=DirectoryBasedExampleDatabase(WindowsPath('c:/Arquivos_Pessoais/PROJETOS/tcc_mba_esalq_mlops/.hypothesis/examples'))
# rootdir: c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops
# configfile: pytest.ini
# plugins: anyio-4.12.1, dash-4.0.0, Faker-20.1.0, hypothesis-6.99.13, asyncio-0.21.1, cov-4.1.0, mock-3.12.0, timeout-2.4.0
# asyncio: mode=Mode.STRICT
# collecting ... collected 29 items / 4 errors
# WARNING: Failed to generate report: No data to report.
#
#
# =================================== ERRORS ====================================
# ___ ERROR collecting tests/unit/features/codificacao/test_aplicar_dummy.py ____
# ImportError while importing test module 'c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\tests\unit\features\codificacao\test_aplicar_dummy.py'.
# Hint: make sure your test modules/packages have valid Python names.
# Traceback:
# .venv\Lib\site-packages\_pytest\python.py:617: in _importtestmodule
#     mod = import_path(self.path, mode=importmode, root=self.config.rootpath)
# .venv\Lib\site-packages\_pytest\pathlib.py:567: in import_path
#     importlib.import_module(module_name)
# C:\Python311\Lib\importlib\__init__.py:126: in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
# <frozen importlib._bootstrap>:1206: in _gcd_import
#     ???
# <frozen importlib._bootstrap>:1178: in _find_and_load
#     ???
# <frozen importlib._bootstrap>:1149: in _find_and_load_unlocked
#     ???
# <frozen importlib._bootstrap>:690: in _load_unlocked
#     ???
# .venv\Lib\site-packages\_pytest\assertion\rewrite.py:186: in exec_module
#     exec(co, module.__dict__)
# tests\unit\features\codificacao\test_aplicar_dummy.py:6: in <module>
#     from src.features.codificacao.aplicar_dummy import aplicar_dummy_encoding
# E   ImportError: cannot import name 'aplicar_dummy_encoding' from 'src.features.codificacao.aplicar_dummy' (c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\features\codificacao\aplicar_dummy.py)
# _ ERROR collecting tests/unit/features/criacao_features/test_calcular_tu_stull.py _
# ImportError while importing test module 'c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\tests\unit\features\criacao_features\test_calcular_tu_stull.py'.
# Hint: make sure your test modules/packages have valid Python names.
# Traceback:
# .venv\Lib\site-packages\_pytest\python.py:617: in _importtestmodule
#     mod = import_path(self.path, mode=importmode, root=self.config.rootpath)
# .venv\Lib\site-packages\_pytest\pathlib.py:567: in import_path
#     importlib.import_module(module_name)
# C:\Python311\Lib\importlib\__init__.py:126: in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
# <frozen importlib._bootstrap>:1206: in _gcd_import
#     ???
# <frozen importlib._bootstrap>:1178: in _find_and_load
#     ???
# <frozen importlib._bootstrap>:1149: in _find_and_load_unlocked
#     ???
# <frozen importlib._bootstrap>:690: in _load_unlocked
#     ???
# .venv\Lib\site-packages\_pytest\assertion\rewrite.py:186: in exec_module
#     exec(co, module.__dict__)
# tests\unit\features\criacao_features\test_calcular_tu_stull.py:5: in <module>
#     from src.processamento.derivadas.calcular_tu_stull import calcular_tu_stull
# E   ModuleNotFoundError: No module named 'src.processamento.derivadas'
# __ ERROR collecting tests/unit/features/normalizacao/test_definir_escalar.py __
# ImportError while importing test module 'c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\tests\unit\features\normalizacao\test_definir_escalar.py'.
# Hint: make sure your test modules/packages have valid Python names.
# Traceback:
# .venv\Lib\site-packages\_pytest\python.py:617: in _importtestmodule
#     mod = import_path(self.path, mode=importmode, root=self.config.rootpath)
# .venv\Lib\site-packages\_pytest\pathlib.py:567: in import_path
#     importlib.import_module(module_name)
# C:\Python311\Lib\importlib\__init__.py:126: in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
# <frozen importlib._bootstrap>:1206: in _gcd_import
#     ???
# <frozen importlib._bootstrap>:1178: in _find_and_load
#     ???
# <frozen importlib._bootstrap>:1149: in _find_and_load_unlocked
#     ???
# <frozen importlib._bootstrap>:690: in _load_unlocked
#     ???
# .venv\Lib\site-packages\_pytest\assertion\rewrite.py:186: in exec_module
#     exec(co, module.__dict__)
# tests\unit\features\normalizacao\test_definir_escalar.py:4: in <module>
#     from src.processamento.normalizacao.pick_scaler import pick_scaler
# E   ModuleNotFoundError: No module named 'src.processamento.normalizacao'
# ____ ERROR collecting tests/unit/features/normalizacao/test_normalizar.py _____
# ImportError while importing test module 'c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\tests\unit\features\normalizacao\test_normalizar.py'.
# Hint: make sure your test modules/packages have valid Python names.
# Traceback:
# .venv\Lib\site-packages\_pytest\python.py:617: in _importtestmodule
#     mod = import_path(self.path, mode=importmode, root=self.config.rootpath)
# .venv\Lib\site-packages\_pytest\pathlib.py:567: in import_path
#     importlib.import_module(module_name)
# C:\Python311\Lib\importlib\__init__.py:126: in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
# <frozen importlib._bootstrap>:1206: in _gcd_import
#     ???
# <frozen importlib._bootstrap>:1178: in _find_and_load
#     ???
# <frozen importlib._bootstrap>:1149: in _find_and_load_unlocked
#     ???
# <frozen importlib._bootstrap>:690: in _load_unlocked
#     ???
# .venv\Lib\site-packages\_pytest\assertion\rewrite.py:186: in exec_module
#     exec(co, module.__dict__)
# tests\unit\features\normalizacao\test_normalizar.py:5: in <module>
#     from src.processamento.normalizacao.normalizar import normalizar
# E   ModuleNotFoundError: No module named 'src.processamento.normalizacao'
#
# ---------- coverage: platform win32, python 3.11.0-final-0 -----------
#
# =========================== short test summary info ===========================
# ERROR tests/unit/features/codificacao/test_aplicar_dummy.py
# ERROR tests/unit/features/criacao_features/test_calcular_tu_stull.py
# ERROR tests/unit/features/normalizacao/test_definir_escalar.py
# ERROR tests/unit/features/normalizacao/test_normalizar.py
# !!!!!!!!!!!!!!!!!!! Interrupted: 4 errors during collection !!!!!!!!!!!!!!!!!!!
# ============================== 4 errors in 2.00s ==============================
# c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\.venv\Lib\site-packages\coverage\inorout.py:497: CoverageWarning: Module funcoes was never imported. (module-not-imported); see https://coverage.readthedocs.io/en/7.13.1/messages.html#warning-module-not-imported
#   self.warn(f"Module {pkg} was never imported.", slug="module-not-imported")
# c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\.venv\Lib\site-packages\coverage\inorout.py:497: CoverageWarning: Module api was never imported. (module-not-imported); see https://coverage.readthedocs.io/en/7.13.1/messages.html#warning-module-not-imported
#   self.warn(f"Module {pkg} was never imported.", slug="module-not-imported")
# c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\.venv\Lib\site-packages\coverage\control.py:958: CoverageWarning: No data was collected. (no-data-collected); see https://coverage.readthedocs.io/en/7.13.1/messages.html#warning-no-data-collected
#   self._warn("No data was collected.", slug="no-data-collected")
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq\.venv\Lib\site-packages\pytest_cov\plugin.py:312: CovReportWarning: Failed to generate report: No data to report.

# %% [markdown]
# ### Testes de Treinamento

# %%
# Testa módulo de treinamento
tests_path = str(PROJECT_ROOT / 'tests' / 'unit' / 'treinamento')
# !python -m pytest "{tests_path}" -v
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.0, pytest-7.4.3, pluggy-1.6.0 -- c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\.venv\Scripts\python.exe
# cachedir: .pytest_cache
# hypothesis profile 'default' -> database=DirectoryBasedExampleDatabase(WindowsPath('c:/Arquivos_Pessoais/PROJETOS/tcc_mba_esalq_mlops/.hypothesis/examples'))
# rootdir: c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops
# configfile: pytest.ini
# plugins: anyio-4.12.1, dash-4.0.0, Faker-20.1.0, hypothesis-6.99.13, asyncio-0.21.1, cov-4.1.0, mock-3.12.0, timeout-2.4.0
# asyncio: mode=Mode.STRICT
# collecting ... collected 61 items / 3 errors
# WARNING: Failed to generate report: No data to report.
#
#
# =================================== ERRORS ====================================
# __ ERROR collecting tests/unit/treinamento/avaliacao/test_avaliar_modelo.py ___
# ImportError while importing test module 'c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\tests\unit\treinamento\avaliacao\test_avaliar_modelo.py'.
# Hint: make sure your test modules/packages have valid Python names.
# Traceback:
# .venv\Lib\site-packages\_pytest\python.py:617: in _importtestmodule
#     mod = import_path(self.path, mode=importmode, root=self.config.rootpath)
# .venv\Lib\site-packages\_pytest\pathlib.py:567: in import_path
#     importlib.import_module(module_name)
# C:\Python311\Lib\importlib\__init__.py:126: in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
# <frozen importlib._bootstrap>:1206: in _gcd_import
#     ???
# <frozen importlib._bootstrap>:1178: in _find_and_load
#     ???
# <frozen importlib._bootstrap>:1149: in _find_and_load_unlocked
#     ???
# <frozen importlib._bootstrap>:690: in _load_unlocked
#     ???
# .venv\Lib\site-packages\_pytest\assertion\rewrite.py:186: in exec_module
#     exec(co, module.__dict__)
# tests\unit\treinamento\avaliacao\test_avaliar_modelo.py:10: in <module>
#     from src.treinamento.avaliar_modelo import avaliar_modelo
# E   ModuleNotFoundError: No module named 'src.treinamento.avaliar_modelo'
# __ ERROR collecting tests/unit/treinamento/avaliacao/test_fazer_predicoes.py __
# ImportError while importing test module 'c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\tests\unit\treinamento\avaliacao\test_fazer_predicoes.py'.
# Hint: make sure your test modules/packages have valid Python names.
# Traceback:
# .venv\Lib\site-packages\_pytest\python.py:617: in _importtestmodule
#     mod = import_path(self.path, mode=importmode, root=self.config.rootpath)
# .venv\Lib\site-packages\_pytest\pathlib.py:567: in import_path
#     importlib.import_module(module_name)
# C:\Python311\Lib\importlib\__init__.py:126: in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
# <frozen importlib._bootstrap>:1206: in _gcd_import
#     ???
# <frozen importlib._bootstrap>:1178: in _find_and_load
#     ???
# <frozen importlib._bootstrap>:1149: in _find_and_load_unlocked
#     ???
# <frozen importlib._bootstrap>:690: in _load_unlocked
#     ???
# .venv\Lib\site-packages\_pytest\assertion\rewrite.py:186: in exec_module
#     exec(co, module.__dict__)
# tests\unit\treinamento\avaliacao\test_fazer_predicoes.py:9: in <module>
#     from src.treinamento.fazer_predicoes import fazer_predicoes
# E   ModuleNotFoundError: No module named 'src.treinamento.fazer_predicoes'
# _ ERROR collecting tests/unit/treinamento/treino/test_treinar_modelo_base.py __
# ImportError while importing test module 'c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\tests\unit\treinamento\treino\test_treinar_modelo_base.py'.
# Hint: make sure your test modules/packages have valid Python names.
# Traceback:
# .venv\Lib\site-packages\_pytest\python.py:617: in _importtestmodule
#     mod = import_path(self.path, mode=importmode, root=self.config.rootpath)
# .venv\Lib\site-packages\_pytest\pathlib.py:567: in import_path
#     importlib.import_module(module_name)
# C:\Python311\Lib\importlib\__init__.py:126: in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
# <frozen importlib._bootstrap>:1206: in _gcd_import
#     ???
# <frozen importlib._bootstrap>:1178: in _find_and_load
#     ???
# <frozen importlib._bootstrap>:1149: in _find_and_load_unlocked
#     ???
# <frozen importlib._bootstrap>:690: in _load_unlocked
#     ???
# .venv\Lib\site-packages\_pytest\assertion\rewrite.py:186: in exec_module
#     exec(co, module.__dict__)
# tests\unit\treinamento\treino\test_treinar_modelo_base.py:10: in <module>
#     from src.treinamento.treinar_modelo_base import treinar_modelo_base
# E   ModuleNotFoundError: No module named 'src.treinamento.treinar_modelo_base'
#
# ---------- coverage: platform win32, python 3.11.0-final-0 -----------
#
# =========================== short test summary info ===========================
# ERROR tests/unit/treinamento/avaliacao/test_avaliar_modelo.py
# ERROR tests/unit/treinamento/avaliacao/test_fazer_predicoes.py
# ERROR tests/unit/treinamento/treino/test_treinar_modelo_base.py
# !!!!!!!!!!!!!!!!!!! Interrupted: 3 errors during collection !!!!!!!!!!!!!!!!!!!
# ============================== 3 errors in 6.25s ==============================
# c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\.venv\Lib\site-packages\coverage\inorout.py:497: CoverageWarning: Module funcoes was never imported. (module-not-imported); see https://coverage.readthedocs.io/en/7.13.1/messages.html#warning-module-not-imported
#   self.warn(f"Module {pkg} was never imported.", slug="module-not-imported")
# c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\.venv\Lib\site-packages\coverage\inorout.py:497: CoverageWarning: Module api was never imported. (module-not-imported); see https://coverage.readthedocs.io/en/7.13.1/messages.html#warning-module-not-imported
#   self.warn(f"Module {pkg} was never imported.", slug="module-not-imported")
# c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\.venv\Lib\site-packages\coverage\control.py:958: CoverageWarning: No data was collected. (no-data-collected); see https://coverage.readthedocs.io/en/7.13.1/messages.html#warning-no-data-collected
#   self._warn("No data was collected.", slug="no-data-collected")
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq\.venv\Lib\site-packages\pytest_cov\plugin.py:312: CovReportWarning: Failed to generate report: No data to report.

# %% [markdown]
# ### Testes de Pipelines

# %%
# Testa pipelines (processamento, features, treinamento)
tests_path = str(PROJECT_ROOT / 'tests' / 'unit' / 'pipelines')
# !python -m pytest "{tests_path}" -v
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.0, pytest-7.4.3, pluggy-1.6.0 -- c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\.venv\Scripts\python.exe
# cachedir: .pytest_cache
# hypothesis profile 'default' -> database=DirectoryBasedExampleDatabase(WindowsPath('c:/Arquivos_Pessoais/PROJETOS/tcc_mba_esalq_mlops/.hypothesis/examples'))
# rootdir: c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops
# configfile: pytest.ini
# plugins: anyio-4.12.1, dash-4.0.0, Faker-20.1.0, hypothesis-6.99.13, asyncio-0.21.1, cov-4.1.0, mock-3.12.0, timeout-2.4.0
# asyncio: mode=Mode.STRICT
# collecting ... collected 27 items
#
# tests/unit/pipelines/test_pipeline_completo.py::test_pipeline_completo_mock FAILED [  3%]
# tests/unit/pipelines/test_pipeline_features.py::TestPipelineFeatures::test_pipeline_basico PASSED [  7%]
# tests/unit/pipelines/test_pipeline_features.py::TestPipelineFeatures::test_codificacao_label PASSED [ 11%]
# tests/unit/pipelines/test_pipeline_features.py::TestPipelineFeatures::test_codificacao_onehot PASSED [ 14%]
# tests/unit/pipelines/test_pipeline_features.py::TestPipelineFeatures::test_normalizacao_todas_colunas PASSED [ 18%]
# tests/unit/pipelines/test_pipeline_features.py::TestPipelineFeatures::test_normalizacao_colunas_especificas PASSED [ 22%]
# tests/unit/pipelines/test_pipeline_features.py::TestPipelineFeatures::test_features_derivadas FAILED [ 25%]
# tests/unit/pipelines/test_pipeline_features.py::TestPipelineFeatures::test_pipeline_completo FAILED [ 29%]
# tests/unit/pipelines/test_pipeline_features.py::TestPipelineFeatures::test_ordem_operacoes FAILED [ 33%]
# tests/unit/pipelines/test_pipeline_features.py::TestPipelineFeatures::test_preserva_original PASSED [ 37%]
# tests/unit/pipelines/test_pipeline_features.py::TestPipelineFeatures::test_colunas_inexistentes PASSED [ 40%]
# tests/unit/pipelines/test_pipeline_processamento.py::test_pipeline_processamento_basico PASSED [ 44%]
# tests/unit/pipelines/test_pipeline_processamento.py::test_pipeline_padroniza_nomes_colunas PASSED [ 48%]
# tests/unit/pipelines/test_pipeline_processamento.py::test_pipeline_conversao_tipos FAILED [ 51%]
# tests/unit/pipelines/test_pipeline_processamento.py::test_pipeline_substituicoes PASSED [ 55%]
# tests/unit/pipelines/test_pipeline_processamento.py::test_pipeline_imputacao_numerica PASSED [ 59%]
# tests/unit/pipelines/test_pipeline_processamento.py::test_pipeline_imputacao_categorica PASSED [ 62%]
# tests/unit/pipelines/test_pipeline_processamento.py::test_pipeline_imputacao_customizada PASSED [ 66%]
# tests/unit/pipelines/test_pipeline_processamento.py::test_pipeline_agrupamento_temporal PASSED [ 70%]
# tests/unit/pipelines/test_pipeline_processamento.py::test_pipeline_sem_agrupamento_temporal PASSED [ 74%]
# tests/unit/pipelines/test_pipeline_processamento.py::test_pipeline_nao_modifica_original PASSED [ 77%]
# tests/unit/pipelines/test_pipeline_processamento.py::test_pipeline_shape_preservado PASSED [ 81%]
# tests/unit/pipelines/test_pipeline_processamento.py::test_pipeline_com_dataframe_vazio PASSED [ 85%]
# tests/unit/pipelines/test_pipeline_processamento.py::test_pipeline_parametros_defaults PASSED [ 88%]
# tests/unit/pipelines/test_pipeline_treinamento_unified.py::test_treinar_pipeline_completo_classificacao FAILED [ 92%]
# tests/unit/pipelines/test_pipeline_treinamento_unified.py::test_treinar_pipeline_completo_regressao FAILED [ 96%]
# tests/unit/pipelines/test_pipeline_treinamento_unified.py::test_treinar_rapido FAILED [100%]WARNING: Failed to generate report: No data to report.
#
#
#
# ================================== FAILURES ===================================
# _________________________ test_pipeline_completo_mock _________________________
# C:\Python311\Lib\unittest\mock.py:1356: in patched
#     with self.decoration_helper(patched,
# C:\Python311\Lib\contextlib.py:137: in __enter__
#     return next(self.gen)
# C:\Python311\Lib\unittest\mock.py:1338: in decoration_helper
#     arg = exit_stack.enter_context(patching)
# C:\Python311\Lib\contextlib.py:502: in enter_context
#     result = _enter(cm)
# C:\Python311\Lib\unittest\mock.py:1427: in __enter__
#     original, local = self.get_original()
# C:\Python311\Lib\unittest\mock.py:1400: in get_original
#     raise AttributeError(
# E   AttributeError: <module 'src.pipelines.pipeline_completo' from 'c:\\Arquivos_Pessoais\\PROJETOS\\tcc_mba_esalq_mlops\\src\\pipelines\\pipeline_completo.py'> does not have the attribute 'treinar_pipeline_completo'
# ________________ TestPipelineFeatures.test_features_derivadas _________________
# tests\unit\pipelines\test_pipeline_features.py:117: in test_features_derivadas
#     assert 'imc' in df_feat.columns
# E   AssertionError: assert 'imc' in Index(['temperatura', 'umidade', 'peso', 'altura', 'sexo', 'vestimenta',\n       'mes-ano', 'IMC'],\n      dtype='object')
# E    +  where Index(['temperatura', 'umidade', 'peso', 'altura', 'sexo', 'vestimenta',\n       'mes-ano', 'IMC'],\n      dtype='object') =     temperatura    umidade       peso  ...  vestimenta  mes-ano            IMC\n0     22.490802  31.885751  82.101582  ...        leve  2024-01  352641.195977\n1     34.014286  68.184625  54.206998  ...       media  2024-01  173873.214604\n2     29.639879  48.861359  58.081436  ...      pesada  2024-01  185325.417972\n3     26.973170  60.514241  94.927709  ...      pesada  2024-01  286987.993429\n4     18.120373  84.453988  80.321453  ...       media  2024-01  231411.296350\n..          ...        ...        ...  ...         ...      ...            ...\n95    24.875912  50.952574  76.112163  ...        leve  2024-04  197043.262919\n96    25.454657  73.557341  88.499678  ...       media  2024-04  237784.921604\n97    23.550820  83.826616  60.791051  ...        leve  2024-04  206807.454224\n98    15.508383  83.225185  81.144524  ...       media  2024-04  230703.899454\n99    17.157829  76.792533  54.267373  ...      pesada  2024-04  153987.211960\n\n[100 rows x 8 columns].columns
# ---------------------------- Captured stdout call -----------------------------
# 🎨 Iniciando pipeline de FEATURES...
#   1️⃣ Criando features derivadas (2 tipos)...
# ✅ Pipeline FEATURES concluído! Shape final: (100, 8)
#    Novas colunas criadas: 1
# _________________ TestPipelineFeatures.test_pipeline_completo _________________
# tests\unit\pipelines\test_pipeline_features.py:135: in test_pipeline_completo
#     assert 'imc' in df_feat.columns
# E   AssertionError: assert 'imc' in Index(['temperatura', 'umidade', 'peso', 'altura', 'sexo', 'vestimenta',\n       'mes-ano', 'IMC', 'sexo_cod', 'vestimenta_cod', 'temperatura_norm',\n       'umidade_norm', 'peso_norm', 'altura_norm', 'IMC_norm', 'sexo_cod_norm',\n       'vestimenta_cod_norm'],\n      dtype='object')
# E    +  where Index(['temperatura', 'umidade', 'peso', 'altura', 'sexo', 'vestimenta',\n       'mes-ano', 'IMC', 'sexo_cod', 'vestimenta_cod', 'temperatura_norm',\n       'umidade_norm', 'peso_norm', 'altura_norm', 'IMC_norm', 'sexo_cod_norm',\n       'vestimenta_cod_norm'],\n      dtype='object') =     temperatura    umidade  ...  sexo_cod_norm  vestimenta_cod_norm\n0     22.490802  31.885751  ...      -0.907485            -1.105072\n1     34.014286  68.184625  ...       1.101946             0.118401\n2     29.639879  48.861359  ...      -0.907485             1.341873\n3     26.973170  60.514241  ...      -0.907485             1.341873\n4     18.120373  84.453988  ...       1.101946             0.118401\n..          ...        ...  ...            ...                  ...\n95    24.875912  50.952574  ...       1.118034            -1.016001\n96    25.454657  73.557341  ...       1.118034             0.127000\n97    23.550820  83.826616  ...       1.118034            -1.016001\n98    15.508383  83.225185  ...      -0.894427             0.127000\n99    17.157829  76.792533  ...      -0.894427             1.270001\n\n[100 rows x 17 columns].columns
# ---------------------------- Captured stdout call -----------------------------
# 🎨 Iniciando pipeline de FEATURES...
#   1️⃣ Criando features derivadas (1 tipos)...
#   2️⃣ Aplicando codificação (label)...
#   3️⃣ Aplicando normalização (standard)...
# ✅ Pipeline FEATURES concluído! Shape final: (100, 17)
#    Novas colunas criadas: 10
# __________________ TestPipelineFeatures.test_ordem_operacoes __________________
# tests\unit\pipelines\test_pipeline_features.py:158: in test_ordem_operacoes
#     assert 'imc' in df_feat.columns
# E   AssertionError: assert 'imc' in Index(['temperatura', 'umidade', 'peso', 'altura', 'sexo', 'vestimenta',\n       'mes-ano', 'IMC', 'sexo_cod', 'temperatura_norm', 'umidade_norm',\n       'peso_norm', 'altura_norm', 'IMC_norm', 'sexo_cod_norm'],\n      dtype='object')
# E    +  where Index(['temperatura', 'umidade', 'peso', 'altura', 'sexo', 'vestimenta',\n       'mes-ano', 'IMC', 'sexo_cod', 'temperatura_norm', 'umidade_norm',\n       'peso_norm', 'altura_norm', 'IMC_norm', 'sexo_cod_norm'],\n      dtype='object') =     temperatura    umidade       peso  ...  altura_norm  IMC_norm sexo_cod_norm\n0     22.490802  31.885751  82.101582  ...    -1.668784  1.428324     -0.907485\n1     34.014286  68.184625  54.206998  ...     0.119192 -1.040245      1.101946\n2     29.639879  48.861359  58.081436  ...     0.153785 -0.882104     -0.907485\n3     26.973170  60.514241  94.927709  ...     0.514586  0.521733     -0.907485\n4     18.120373  84.453988  80.321453  ...     0.845071 -0.245714      1.101946\n..          ...        ...        ...  ...          ...       ...           ...\n95    24.875912  50.952574  76.112163  ...     1.395671 -0.357650      1.118034\n96    25.454657  73.557341  88.499678  ...     1.065392  0.550619      1.118034\n97    23.550820  83.826616  60.791051  ...    -0.895054 -0.139973      1.118034\n98    15.508383  83.225185  81.144524  ...     0.574427  0.392759     -0.894427\n99    17.157829  76.792533  54.267373  ...     0.591190 -1.317515     -0.894427\n\n[100 rows x 15 columns].columns
# ---------------------------- Captured stdout call -----------------------------
# 🎨 Iniciando pipeline de FEATURES...
#   1️⃣ Criando features derivadas (1 tipos)...
#   2️⃣ Aplicando codificação (label)...
#   3️⃣ Aplicando normalização (standard)...
# ✅ Pipeline FEATURES concluído! Shape final: (100, 15)
#    Novas colunas criadas: 8
# ________________________ test_pipeline_conversao_tipos ________________________
# tests\unit\pipelines\test_pipeline_processamento.py:89: in test_pipeline_conversao_tipos
#     assert pd.api.types.is_datetime64_any_dtype(resultado['hora'])
# E   AssertionError: assert False
# E    +  where False = <function is_datetime64_any_dtype at 0x0000028A6C650A40>(0    10:00:00\n1    11:00:00\nName: hora, dtype: object)
# E    +    where <function is_datetime64_any_dtype at 0x0000028A6C650A40> = <module 'pandas.api.types' from 'c:\\Arquivos_Pessoais\\PROJETOS\\tcc_mba_esalq_mlops\\.venv\\Lib\\site-packages\\pandas\\api\\types\\__init__.py'>.is_datetime64_any_dtype
# E    +      where <module 'pandas.api.types' from 'c:\\Arquivos_Pessoais\\PROJETOS\\tcc_mba_esalq_mlops\\.venv\\Lib\\site-packages\\pandas\\api\\types\\__init__.py'> = <module 'pandas.api' from 'c:\\Arquivos_Pessoais\\PROJETOS\\tcc_mba_esalq_mlops\\.venv\\Lib\\site-packages\\pandas\\api\\__init__.py'>.types
# E    +        where <module 'pandas.api' from 'c:\\Arquivos_Pessoais\\PROJETOS\\tcc_mba_esalq_mlops\\.venv\\Lib\\site-packages\\pandas\\api\\__init__.py'> = pd.api
# ---------------------------- Captured stdout call -----------------------------
# 🔄 Iniciando pipeline de processamento BASE...
#   1️⃣ Aplicando substituições de limpeza...
#   2️⃣ Convertendo tipos de dados...
#   3️⃣ Imputando valores faltantes...
#   4️⃣ Criando agrupamento temporal...
# ✅ Pipeline BASE concluído! Shape final: (2, 6)
# ________________ test_treinar_pipeline_completo_classificacao _________________
# tests\unit\pipelines\test_pipeline_treinamento_unified.py:48: in test_treinar_pipeline_completo_classificacao
#     resultado = treinar_pipeline_completo(
# src\pipelines\pipeline_treinamento_unified.py:153: in treinar_pipeline_completo
#     tabela_classificada = classificar_metricas(
# src\treinamento\avaliacao\classificar_metricas.py:31: in classificar_metricas
#     raise ValueError(f"Métricas não encontradas na tabela: {metricas_faltantes}")
# E   ValueError: Métricas não encontradas na tabela: ['AUC', 'Recall', 'Prec.', 'F1', 'Kappa', 'MCC']
# __________________ test_treinar_pipeline_completo_regressao ___________________
# tests\unit\pipelines\test_pipeline_treinamento_unified.py:94: in test_treinar_pipeline_completo_regressao
#     resultado = treinar_pipeline_completo(
# src\pipelines\pipeline_treinamento_unified.py:153: in treinar_pipeline_completo
#     tabela_classificada = classificar_metricas(
# src\treinamento\avaliacao\classificar_metricas.py:31: in classificar_metricas
#     raise ValueError(f"Métricas não encontradas na tabela: {metricas_faltantes}")
# E   ValueError: Métricas não encontradas na tabela: ['MAE', 'MSE', 'RMSE', 'RMSLE', 'MAPE']
# _____________________________ test_treinar_rapido _____________________________
# tests\unit\pipelines\test_pipeline_treinamento_unified.py:129: in test_treinar_rapido
#     resultado = treinar_rapido(
# src\pipelines\pipeline_treinamento_unified.py:270: in treinar_rapido
#     resultado = treinar_pipeline_completo(
# src\pipelines\pipeline_treinamento_unified.py:153: in treinar_pipeline_completo
#     tabela_classificada = classificar_metricas(
# src\treinamento\avaliacao\classificar_metricas.py:31: in classificar_metricas
#     raise ValueError(f"Métricas não encontradas na tabela: {metricas_faltantes}")
# E   ValueError: Métricas não encontradas na tabela: ['AUC', 'Recall', 'Prec.', 'F1', 'Kappa', 'MCC']
#
# ---------- coverage: platform win32, python 3.11.0-final-0 -----------
#
# =========================== short test summary info ===========================
# FAILED tests/unit/pipelines/test_pipeline_completo.py::test_pipeline_completo_mock - AttributeError: <module 'src.pipelines.pipeline_completo' from 'c:\\Arquivo...
# FAILED tests/unit/pipelines/test_pipeline_features.py::TestPipelineFeatures::test_features_derivadas - AssertionError: assert 'imc' in Index(['temperatura', 'umidade', 'peso', 'a...
# FAILED tests/unit/pipelines/test_pipeline_features.py::TestPipelineFeatures::test_pipeline_completo - AssertionError: assert 'imc' in Index(['temperatura', 'umidade', 'peso', 'a...
# FAILED tests/unit/pipelines/test_pipeline_features.py::TestPipelineFeatures::test_ordem_operacoes - AssertionError: assert 'imc' in Index(['temperatura', 'umidade', 'peso', 'a...
# FAILED tests/unit/pipelines/test_pipeline_processamento.py::test_pipeline_conversao_tipos - AssertionError: assert False
# FAILED tests/unit/pipelines/test_pipeline_treinamento_unified.py::test_treinar_pipeline_completo_classificacao - ValueError: Métricas não encontradas na tabela: ['AUC', 'Recall', 'Prec.', ...
# FAILED tests/unit/pipelines/test_pipeline_treinamento_unified.py::test_treinar_pipeline_completo_regressao - ValueError: Métricas não encontradas na tabela: ['MAE', 'MSE', 'RMSE', 'RMS...
# FAILED tests/unit/pipelines/test_pipeline_treinamento_unified.py::test_treinar_rapido - ValueError: Métricas não encontradas na tabela: ['AUC', 'Recall', 'Prec.', ...
# ======================== 8 failed, 19 passed in 5.99s =========================
# c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\.venv\Lib\site-packages\coverage\inorout.py:497: CoverageWarning: Module funcoes was never imported. (module-not-imported); see https://coverage.readthedocs.io/en/7.13.1/messages.html#warning-module-not-imported
#   self.warn(f"Module {pkg} was never imported.", slug="module-not-imported")
# c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\.venv\Lib\site-packages\coverage\inorout.py:497: CoverageWarning: Module api was never imported. (module-not-imported); see https://coverage.readthedocs.io/en/7.13.1/messages.html#warning-module-not-imported
#   self.warn(f"Module {pkg} was never imported.", slug="module-not-imported")
# c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\.venv\Lib\site-packages\coverage\control.py:958: CoverageWarning: No data was collected. (no-data-collected); see https://coverage.readthedocs.io/en/7.13.1/messages.html#warning-no-data-collected
#   self._warn("No data was collected.", slug="no-data-collected")
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq\.venv\Lib\site-packages\pytest_cov\plugin.py:312: CovReportWarning: Failed to generate report: No data to report.

# %% [markdown]
# ### Testes de Processamento

# %%
# Testa processamento (limpeza, imputação, temporal)
tests_path = str(PROJECT_ROOT / 'tests' / 'unit' / 'processamento')
# !python -m pytest "{tests_path}" -v
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.0, pytest-7.4.3, pluggy-1.6.0 -- c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\.venv\Scripts\python.exe
# cachedir: .pytest_cache
# hypothesis profile 'default' -> database=DirectoryBasedExampleDatabase(WindowsPath('c:/Arquivos_Pessoais/PROJETOS/tcc_mba_esalq_mlops/.hypothesis/examples'))
# rootdir: c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops
# configfile: pytest.ini
# plugins: anyio-4.12.1, dash-4.0.0, Faker-20.1.0, hypothesis-6.99.13, asyncio-0.21.1, cov-4.1.0, mock-3.12.0, timeout-2.4.0
# asyncio: mode=Mode.STRICT
# collecting ... collected 65 items / 3 errors
# WARNING: Failed to generate report: No data to report.
#
#
# =================================== ERRORS ====================================
# _______ ERROR collecting tests/unit/processamento/test_limpeza_geral.py _______
# .venv\Lib\site-packages\_pytest\python.py:617: in _importtestmodule
#     mod = import_path(self.path, mode=importmode, root=self.config.rootpath)
# .venv\Lib\site-packages\_pytest\pathlib.py:567: in import_path
#     importlib.import_module(module_name)
# C:\Python311\Lib\importlib\__init__.py:126: in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
# <frozen importlib._bootstrap>:1206: in _gcd_import
#     ???
# <frozen importlib._bootstrap>:1178: in _find_and_load
#     ???
# <frozen importlib._bootstrap>:1149: in _find_and_load_unlocked
#     ???
# <frozen importlib._bootstrap>:690: in _load_unlocked
#     ???
# .venv\Lib\site-packages\_pytest\assertion\rewrite.py:177: in exec_module
#     source_stat, co = _rewrite_test(fn, self.config)
# .venv\Lib\site-packages\_pytest\assertion\rewrite.py:359: in _rewrite_test
#     tree = ast.parse(source, filename=strfn)
# C:\Python311\Lib\ast.py:50: in parse
#     return compile(source, filename, mode, flags,
# E     File "c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\tests\unit\processamento\test_limpeza_geral.py", line 43
# E       )
# E       ^
# E   SyntaxError: unmatched ')'
# _________ ERROR collecting tests/unit/processamento/test_temporal.py __________
# ImportError while importing test module 'c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\tests\unit\processamento\test_temporal.py'.
# Hint: make sure your test modules/packages have valid Python names.
# Traceback:
# .venv\Lib\site-packages\_pytest\python.py:617: in _importtestmodule
#     mod = import_path(self.path, mode=importmode, root=self.config.rootpath)
# .venv\Lib\site-packages\_pytest\pathlib.py:567: in import_path
#     importlib.import_module(module_name)
# C:\Python311\Lib\importlib\__init__.py:126: in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
# <frozen importlib._bootstrap>:1206: in _gcd_import
#     ???
# <frozen importlib._bootstrap>:1178: in _find_and_load
#     ???
# <frozen importlib._bootstrap>:1149: in _find_and_load_unlocked
#     ???
# <frozen importlib._bootstrap>:690: in _load_unlocked
#     ???
# .venv\Lib\site-packages\_pytest\assertion\rewrite.py:186: in exec_module
#     exec(co, module.__dict__)
# tests\unit\processamento\test_temporal.py:8: in <module>
#     from src.processamento.temporal import (
# E   ImportError: cannot import name 'criar_coluna_temporal' from 'src.processamento.temporal' (c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\processamento\temporal\__init__.py)
# ___________ ERROR collecting tests/unit/processamento/test_utils.py ___________
# ImportError while importing test module 'c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\tests\unit\processamento\test_utils.py'.
# Hint: make sure your test modules/packages have valid Python names.
# Traceback:
# .venv\Lib\site-packages\_pytest\python.py:617: in _importtestmodule
#     mod = import_path(self.path, mode=importmode, root=self.config.rootpath)
# .venv\Lib\site-packages\_pytest\pathlib.py:567: in import_path
#     importlib.import_module(module_name)
# C:\Python311\Lib\importlib\__init__.py:126: in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
# <frozen importlib._bootstrap>:1206: in _gcd_import
#     ???
# <frozen importlib._bootstrap>:1178: in _find_and_load
#     ???
# <frozen importlib._bootstrap>:1149: in _find_and_load_unlocked
#     ???
# <frozen importlib._bootstrap>:690: in _load_unlocked
#     ???
# .venv\Lib\site-packages\_pytest\assertion\rewrite.py:186: in exec_module
#     exec(co, module.__dict__)
# tests\unit\processamento\test_utils.py:12: in <module>
#     from funcoes.processamento import (_calcular_imc, _calcular_indice_calor,
# E   ModuleNotFoundError: No module named 'funcoes'
#
# ---------- coverage: platform win32, python 3.11.0-final-0 -----------
#
# =========================== short test summary info ===========================
# ERROR tests/unit/processamento/test_limpeza_geral.py
# ERROR tests/unit/processamento/test_temporal.py
# ERROR tests/unit/processamento/test_utils.py
# !!!!!!!!!!!!!!!!!!! Interrupted: 3 errors during collection !!!!!!!!!!!!!!!!!!!
# ============================== 3 errors in 1.15s ==============================
# c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\.venv\Lib\site-packages\coverage\inorout.py:497: CoverageWarning: Module funcoes was never imported. (module-not-imported); see https://coverage.readthedocs.io/en/7.13.1/messages.html#warning-module-not-imported
#   self.warn(f"Module {pkg} was never imported.", slug="module-not-imported")
# c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\.venv\Lib\site-packages\coverage\inorout.py:497: CoverageWarning: Module api was never imported. (module-not-imported); see https://coverage.readthedocs.io/en/7.13.1/messages.html#warning-module-not-imported
#   self.warn(f"Module {pkg} was never imported.", slug="module-not-imported")
# c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\.venv\Lib\site-packages\coverage\control.py:958: CoverageWarning: No data was collected. (no-data-collected); see https://coverage.readthedocs.io/en/7.13.1/messages.html#warning-no-data-collected
#   self._warn("No data was collected.", slug="no-data-collected")
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq\.venv\Lib\site-packages\pytest_cov\plugin.py:312: CovReportWarning: Failed to generate report: No data to report.

# %% [markdown]
# ## 📊 Relatório de Cobertura de Código
#
# Gera relatório HTML mostrando quais linhas de código estão cobertas por testes.

# %%
# %%time
# Executa testes com relatório de cobertura
tests_path = str(PROJECT_ROOT / 'tests')
src_path = str(PROJECT_ROOT / 'src')
# !python -m pytest "{tests_path}" --cov="{src_path}" --cov-report=html --cov-report=term

print("\n✅ Relatório HTML gerado em: htmlcov/index.html")
print("   Abra o arquivo para ver detalhes da cobertura.")

# %% [markdown]
# ## 📝 Resumo Rápido dos Testes
#
# Executa testes e mostra apenas o resumo final.

# %%
# Executa testes mostrando apenas resumo (sem verbose)
tests_path = str(PROJECT_ROOT / 'tests')
# !python -m pytest "{tests_path}" --tb=line -q
# Out:
# Failed to canonicalize script path

# %% [markdown]
# ## 🔍 Executar Teste Específico
#
# Para executar um teste específico, use o padrão:
# ```
# pytest caminho/arquivo.py::nome_da_funcao_teste
# ```

# %%
# Exemplo: executar teste específico de normalização
test_file = str(PROJECT_ROOT / 'tests' / 'unit' / 'features' / 'normalizacao' / 'test_normalizar.py')
# !python -m pytest "{test_file}::test_normalizar_standard" -v

# %% [markdown]
# ## 🐛 Executar Testes com Debug
#
# Para investigar falhas, use modo verbose com stack trace completo.

# %%
# Executa com output completo e para no primeiro erro
tests_path = str(PROJECT_ROOT / 'tests' / 'unit')
# !python -m pytest "{tests_path}" -v -s -x --tb=long

# %% [markdown]
# ## 📈 Executar Testes End-to-End Principais
#
# Executa apenas os testes de integração mais importantes.

# %%
# %%time
# Testa pipeline end-to-end completo
test_file = str(PROJECT_ROOT / 'tests' / 'integration' / 'test_pipeline_end_to_end.py')
# !pytest {test_file} -v

# %%
# %%time
# Testa cenários reais e edge cases
test_file = str(PROJECT_ROOT / 'tests' / 'integration' / 'test_cenarios_reais.py')
# !pytest {test_file} -v

# %% [markdown]
# ## 🎨 Estatísticas dos Testes
#
# Conta quantos testes existem por categoria.

# %%
from pathlib import Path

tests_dir = PROJECT_ROOT / 'tests'

# Conta testes por categoria
unit_tests = list((tests_dir / 'unit').rglob('test_*.py'))
integration_tests = list((tests_dir / 'integration').rglob('test_*.py'))

print("📊 ESTATÍSTICAS DE TESTES")
print("=" * 50)
print(f"\n✅ Testes Unitários: {len(unit_tests)} arquivos")
print(f"   • Features: {len(list((tests_dir / 'unit' / 'features').rglob('test_*.py')))} testes")
print(f"   • Processamento: {len(list((tests_dir / 'unit' / 'processamento').rglob('test_*.py')))} testes")
print(f"   • Treinamento: {len(list((tests_dir / 'unit' / 'treinamento').rglob('test_*.py')))} testes")
print(f"   • Pipelines: {len(list((tests_dir / 'unit' / 'pipelines').rglob('test_*.py')))} testes")
print(f"   • Utils: {len(list((tests_dir / 'unit' / 'utils').rglob('test_*.py')))} testes")

print(f"\n🔗 Testes de Integração: {len(integration_tests)} arquivos")

print(f"\n📦 TOTAL: {len(unit_tests) + len(integration_tests)} arquivos de teste")
print("=" * 50)

# %% [markdown]
# ## 🔥 Executar Teste Customizado
#
# Use esta célula para executar comandos pytest personalizados.

# %%
# Personalize o comando pytest aqui
import os
os.chdir(PROJECT_ROOT)
comando_custom = "pytest tests/unit/pipelines/test_pipeline_treinamento_unified.py -v"


print(f"🚀 Executando: {comando_custom}\n")!{comando_custom}

# %% [markdown]
# ---
#
# ## 📚 Comandos Úteis Pytest
#
# ### Opções Comuns
# - `-v` : Verbose (mostra cada teste)
# - `-s` : Mostra prints durante testes
# - `-x` : Para no primeiro erro
# - `-k "palavra"` : Executa apenas testes com "palavra" no nome
# - `--tb=short` : Traceback curto
# - `--tb=long` : Traceback completo
# - `--tb=line` : Traceback de uma linha
# - `-q` : Modo quieto (apenas resumo)
# - `--maxfail=N` : Para após N falhas
# - `--lf` : Executa apenas testes que falharam na última execução
# - `--ff` : Executa testes que falharam primeiro
#
# ### Cobertura
# - `--cov=src` : Mede cobertura do código em src/
# - `--cov-report=html` : Gera relatório HTML
# - `--cov-report=term` : Mostra relatório no terminal
#
# ### Marcadores
# - `-m integration` : Executa apenas testes marcados como integração
# - `-m "not slow"` : Pula testes marcados como lentos
#
# ### Exemplos
# ```bash
# # Executar teste específico
# pytest tests/unit/features/test_normalizar.py::test_normalizar_standard
#
# # Executar testes que contém "pipeline" no nome
# pytest -k "pipeline"
#
# # Executar apenas testes que falharam
# pytest --lf
#
# # Executar com cobertura
# pytest --cov=src --cov-report=html
# ```
