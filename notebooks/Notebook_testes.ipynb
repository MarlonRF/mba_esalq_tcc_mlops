# %% [markdown]
# # 🧪 Executar Testes do Projeto
#
# Este notebook permite executar todos os testes do projeto MLOps de forma interativa.
#
# ## Estrutura de Testes
#
# - **Testes Unitários** (`tests/unit/`): Testes rápidos e isolados (55 arquivos)
# - **Testes de Integração** (`tests/integration/`): Testes end-to-end (7 arquivos)
# - **Total**: 62 arquivos de teste
# - **Cobertura**: ~85%

# %% [markdown]
# ## 📦 Setup - Imports e Configuração

# %%
import sys
from pathlib import Path
import subprocess
import pandas as pd
import xml.etree.ElementTree as ET
from pathlib import Path

# Define o diretório raiz do projeto
PROJECT_ROOT = Path.cwd().parent
sys.path.insert(0, str(PROJECT_ROOT))

print(f"📁 Diretório do projeto: {PROJECT_ROOT}")
print(f"📂 Diretório de testes: {PROJECT_ROOT / 'tests'}")
# Out:
# 📁 Diretório do projeto: c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops
# 📂 Diretório de testes: c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\tests

# %% [markdown]
# ## Executar Todos os Testes
#
# Executa todos os testes (unitários + integração).

# %%
# %%time
# Executa todos os testes
tests_path = str(PROJECT_ROOT / 'tests')
# !python -m pytest "{tests_path}" -v --tb=short

# %%
# %%time
# Executa apenas testes unitários
tests_path = str(PROJECT_ROOT / 'tests' / 'unit')
# !python -m pytest "{tests_path}" -v --tb=short

# %% [markdown]
# ## Análise Detalhada dos Resultados
#
# Gera uma tabela detalhada com todos os resultados dos testes.

# %%
# Cria pasta de relatórios
relatorios_dir = PROJECT_ROOT / 'relatorios'
relatorios_dir.mkdir(exist_ok=True)

# Paths completos como na célula 7
tests_path = str(PROJECT_ROOT / 'tests')
xml_path = str(relatorios_dir / 'test_results.xml')

# Executa pytest igual à célula 7 que funciona
result = subprocess.run(
    f'python -m pytest "{tests_path}" --junit-xml="{xml_path}" -v',
    cwd=PROJECT_ROOT,
    capture_output=True,
    text=True,
    shell=True
)

# Verifica se o arquivo foi criado
if not (relatorios_dir / 'test_results.xml').exists():
    display(pd.DataFrame([{
        'Erro': 'Nenhum teste foi executado',
        'Detalhes': 'Verifique se há testes válidos no diretório tests/',
        'Stdout': result.stdout[:300] if result.stdout else 'Vazio',
        'Stderr': result.stderr[:300] if result.stderr else 'Vazio'
    }]))
else:
    # Parse XML
    tree = ET.parse(relatorios_dir / 'test_results.xml')
    root = tree.getroot()
    
    data = []
    for testcase in root.iter('testcase'):
        file_path = testcase.get('file', '')
        name = testcase.get('name', '')
        
        # Status
        if testcase.find('failure') is not None:
            status = 'FALHOU'
            msg = testcase.find('failure').get('message', '')[:100]
        elif testcase.find('error') is not None:
            status = 'ERRO'
            msg = testcase.find('error').get('message', '')[:100]
        elif testcase.find('skipped') is not None:
            status = 'PULOU'
            msg = testcase.find('skipped').get('message', '')[:100]
        else:
            status = 'PASSOU'
            msg = ''
        
        # Módulo
        if 'tests/unit/' in file_path or 'tests\\unit\\' in file_path:
            path_clean = file_path.replace('tests/unit/', '').replace('tests\\unit\\', '')
            modulo = path_clean.split('/')[0].split('\\')[0]
        elif 'tests/integration/' in file_path or 'tests\\integration\\' in file_path:
            modulo = 'integration'
        else:
            modulo = 'root'
        
        arquivo = file_path.split('/')[-1].split('\\')[-1] if file_path else ''
        
        data.append({
            'Módulo': modulo,
            'Arquivo': arquivo,
            'Teste': name,
            'Status': status,
            'Detalhes': msg
        })
    
    df = pd.DataFrame(data)
    
    # Resumo
    resumo = pd.DataFrame([{
        'Total': len(df),
        'Passou': len(df[df['Status'] == 'PASSOU']),
        'Falhou': len(df[df['Status'] == 'FALHOU']),
        'Erro': len(df[df['Status'] == 'ERRO']),
        '⏭Pulou': len(df[df['Status'] == '⏭PULOU'])
    }])
    
    # Por módulo
    por_modulo = df.groupby(['Módulo', 'Status']).size().unstack(fill_value=0)
    
    # Problemas
    problemas = df[df['Status'].isin(['FALHOU', 'ERRO'])][['Módulo', 'Arquivo', 'Teste', 'Status', 'Detalhes']]
    
    # Salva CSVs
    df.to_csv(relatorios_dir / 'resultados_completos.csv', index=False)
    resumo.to_csv(relatorios_dir / 'resumo.csv', index=False)
    por_modulo.to_csv(relatorios_dir / 'por_modulo.csv')
    if len(problemas) > 0:
        problemas.to_csv(relatorios_dir / 'problemas.csv', index=False)
    
    # Display tables
    display(resumo)
    display(por_modulo)
    if len(problemas) > 0:
        display(problemas)
# Out:
# Exception in thread Thread-32 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Python311\Lib\threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "C:\Python311\Lib\threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Python311\Lib\subprocess.py", line 1550, in _readerthread
#     buffer.append(fh.read())
#                   ^^^^^^^^^
#   File "C:\Python311\Lib\encodings\cp1252.py", line 23, in decode
#     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x8f in position 49813: character maps to <undefined>
#    Total  Passou  Falhou  Erro  ⏭Pulou
# 0    302     177     101    12       0
# Status  ERRO  FALHOU  PASSOU  PULOU
# Módulo
# root      12     101     177     12
#     Módulo Arquivo                                 Teste  Status  \
# 4     root          test_pipeline_com_dados_reais_subset  FALHOU
# 8     root            test_artefatos_codificacao_criados  FALHOU
# 9     root           test_artefatos_normalizacao_criados  FALHOU
# 10    root                test_mesmo_dataset_ambos_tipos  FALHOU
# 11    root          test_pipeline_completo_classificacao  FALHOU
# ..     ...     ...                                   ...     ...
# 254   root                    test_treinar_modelo_basico  FALHOU
# 255   root            test_modelo_treinado_faz_predicoes  FALHOU
# 256   root              test_modelo_com_diferentes_tipos  FALHOU
# 273   root                 test_extrai_estimador_pycaret  FALHOU
# 293   root          test_resolver_coluna_alvo_com_hifens  FALHOU
#
#                                               Detalhes
# 4    AssertionError: assert 'imc' in Index(['data',...
# 8    AssertionError: assert 'artefatos_codificacao'...
# 9    AssertionError: assert 'artefatos_normalizacao...
# 10   TypeError: treinar_rapido() got an unexpected ...
# 11   AssertionError: assert 'imc' in Index(['idade'...
# ..                                                 ...
# 254  AttributeError: 'RandomForestClassifier' objec...
# 255  AttributeError: 'LogisticRegression' object ha...
# 256  AttributeError: 'RandomForestClassifier' objec...
# 273  AssertionError: assert <treinamento.utils.test...
# 293   AssertionError: assert None == 'target-variable'
#
# [113 rows x 5 columns]

# %% [markdown]
# ## 🔗 Executar Apenas Testes de Integração
#
# Testes de integração são mais lentos e testam fluxos completos end-to-end.

# %%
# %%time
# Executa apenas testes de integração
tests_path = str(PROJECT_ROOT / 'tests' / 'integration')
# !python -m pytest "{tests_path}" -v --tb=short
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.0, pytest-7.4.3, pluggy-1.6.0 -- c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\.venv\Scripts\python.exe
# cachedir: .pytest_cache
# hypothesis profile 'default' -> database=DirectoryBasedExampleDatabase(WindowsPath('c:/Arquivos_Pessoais/PROJETOS/tcc_mba_esalq_mlops/notebooks/.hypothesis/examples'))
# rootdir: c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops
# configfile: pytest.ini
# plugins: anyio-4.12.1, dash-4.0.0, Faker-20.1.0, hypothesis-6.99.13, asyncio-0.21.1, cov-4.1.0, mock-3.12.0, timeout-2.4.0
# asyncio: mode=Mode.STRICT
# collecting ... collected 12 items / 4 skipped
#
# ..\tests\integration\test_cenarios_reais.py::TestCenarioRealConfortoTermico::test_pipeline_com_dados_reais_subset FAILED [  8%]
# ..\tests\integration\test_cenarios_reais.py::TestCenariosEdgeCases::test_dados_com_muitos_missings PASSED [ 16%]
# ..\tests\integration\test_cenarios_reais.py::TestCenariosEdgeCases::test_dados_minimos PASSED [ 25%]
# ..\tests\integration\test_cenarios_reais.py::TestCenariosEdgeCases::test_coluna_categorica_valor_unico PASSED [ 33%]
# ..\tests\integration\test_cenarios_reais.py::TestValidacaoArtefatos::test_artefatos_codificacao_criados FAILED [ 41%]
# ..\tests\integration\test_cenarios_reais.py::TestValidacaoArtefatos::test_artefatos_normalizacao_criados FAILED [ 50%]
# ..\tests\integration\test_cenarios_reais.py::TestComparacaoClassificacaoRegressao::test_mesmo_dataset_ambos_tipos FAILED [ 58%]
# ..\tests\integration\test_pipeline_end_to_end.py::TestFluxoCompletoClassificacao::test_pipeline_completo_classificacao FAILED [ 66%]
# ..\tests\integration\test_pipeline_end_to_end.py::TestFluxoCompletoRegressao::test_pipeline_completo_regressao FAILED [ 75%]
# ..\tests\integration\test_pipeline_end_to_end.py::TestFluxoCompletoComOtimizacao::test_pipeline_com_otimizacao_classificacao FAILED [ 83%]
# ..\tests\integration\test_pipeline_end_to_end.py::TestConsistenciaDados::test_sem_perda_excessiva_de_dados PASSED [ 91%]
# ..\tests\integration\test_pipeline_end_to_end.py::TestConsistenciaDados::test_tipos_colunas_consistentes PASSED [100%]
#
# ================================== FAILURES ===================================
# _____ TestCenarioRealConfortoTermico.test_pipeline_com_dados_reais_subset _____
# ..\tests\integration\test_cenarios_reais.py:58: in test_pipeline_com_dados_reais_subset
#     assert 'imc' in df_feat.columns
# E   AssertionError: assert 'imc' in Index(['data', 'hora', 'idade', 'sexo', 'peso', 'altura', 'vestimenta', 'p1',\n       'p2', 'p3', 'p4', 'p5', 'p6', 'p7', 'p8', 'tev', 'utci', 'sst', 'ste',\n       'psti', 'wbgt', 'wci', 'tek', 'te', 'pst', 'tmedia', 'tmax', 'tmin',\n       'tu', 'ur', 'ur_max', 'ur_min', 'rsolarmed', 'rsolartot', 'vel_vento',\n       'dir_vento', 'sd_dirvento', 'vel_vento_max', 'dir_max_vento',\n       'chuva_tot', 'mes-ano', 'IMC', 'heat_index', 'dew_point', 'sexo_cod',\n       'vestimenta_cod', 'idade_norm', 'peso_norm', 'altura_norm', 'p1_norm',\n       'p2_norm', 'p3_norm', 'p4_norm', 'p5_norm', 'p6_norm', 'p7_norm',\n       'p8_norm', 'tmedia_norm', 'tmax_norm', 'tmin_norm', 'tu_norm',\n       'ur_norm', 'ur_max_norm', 'ur_min_norm', 'rsolarmed_norm',\n       'rsolartot_norm', 'vel_vento_norm', 'sd_dirvento_norm',\n       'vel_vento_max_norm', 'chuva_tot_norm', 'IMC_norm', 'heat_index_norm',\n       'dew_point_norm', 'sexo_cod_norm', 'vestimenta_cod_norm'],\n      dtype='object')
# E    +  where Index(['data', 'hora', 'idade', 'sexo', 'peso', 'altura', 'vestimenta', 'p1',\n       'p2', 'p3', 'p4', 'p5', 'p6', 'p7', 'p8', 'tev', 'utci', 'sst', 'ste',\n       'psti', 'wbgt', 'wci', 'tek', 'te', 'pst', 'tmedia', 'tmax', 'tmin',\n       'tu', 'ur', 'ur_max', 'ur_min', 'rsolarmed', 'rsolartot', 'vel_vento',\n       'dir_vento', 'sd_dirvento', 'vel_vento_max', 'dir_max_vento',\n       'chuva_tot', 'mes-ano', 'IMC', 'heat_index', 'dew_point', 'sexo_cod',\n       'vestimenta_cod', 'idade_norm', 'peso_norm', 'altura_norm', 'p1_norm',\n       'p2_norm', 'p3_norm', 'p4_norm', 'p5_norm', 'p6_norm', 'p7_norm',\n       'p8_norm', 'tmedia_norm', 'tmax_norm', 'tmin_norm', 'tu_norm',\n       'ur_norm', 'ur_max_norm', 'ur_min_norm', 'rsolarmed_norm',\n       'rsolartot_norm', 'vel_vento_norm', 'sd_dirvento_norm',\n       'vel_vento_max_norm', 'chuva_tot_norm', 'IMC_norm', 'heat_index_norm',\n       'dew_point_norm', 'sexo_cod_norm', 'vestimenta_cod_norm'],\n      dtype='object') =          data      hora  ...  sexo_cod_norm vestimenta_cod_norm\n0  2015-08-05  09:10:00  ...      -0.816497           -1.491914\n1  2015-08-05  09:10:00  ...      -0.816497            0.670280\n2  2015-08-05  09:10:00  ...       1.224745            0.670280\n3  2015-08-05  09:10:00  ...      -0.816497            0.670280\n4  2015-08-05  09:10:00  ...      -0.816497            0.670280\n..        ...       ...  ...            ...                 ...\n95 2015-08-05  11:40:00  ...       1.224745           -1.491914\n96 2015-08-05  11:50:00  ...      -0.816497           -1.491914\n97 2015-08-05  11:50:00  ...      -0.816497           -1.491914\n98 2015-08-05  11:50:00  ...       1.224745            0.670280\n99 2015-08-05  11:50:00  ...      -0.816497            0.670280\n\n[100 rows x 75 columns].columns
# ---------------------------- Captured stdout call -----------------------------
# 🔄 Iniciando pipeline de processamento BASE...
#   1️⃣ Aplicando substituições de limpeza...
#   2️⃣ Convertendo tipos de dados...
#   3️⃣ Imputando valores faltantes...
#   4️⃣ Criando agrupamento temporal...
# ✅ Pipeline BASE concluído! Shape final: (100, 41)
# 🎨 Iniciando pipeline de FEATURES...
#   1️⃣ Criando features derivadas (3 tipos)...
#   2️⃣ Aplicando codificação (label)...
#   3️⃣ Aplicando normalização (standard)...
# ✅ Pipeline FEATURES concluído! Shape final: (100, 75)
#    Novas colunas criadas: 34
# __________ TestValidacaoArtefatos.test_artefatos_codificacao_criados __________
# ..\tests\integration\test_cenarios_reais.py:175: in test_artefatos_codificacao_criados
#     assert 'artefatos_codificacao' in artefatos
# E   AssertionError: assert 'artefatos_codificacao' in {'colunas_normalizadas': ['numerica_norm'], 'mapeamentos_codificacao': {}}
# ---------------------------- Captured stdout call -----------------------------
# 🔄 Iniciando pipeline de processamento BASE...
#   1️⃣ Aplicando substituições de limpeza...
#   2️⃣ Convertendo tipos de dados...
#   3️⃣ Imputando valores faltantes...
#   4️⃣ Criando agrupamento temporal...
# ✅ Pipeline BASE concluído! Shape final: (5, 3)
# 🎨 Iniciando pipeline de FEATURES...
#   2️⃣ Aplicando codificação (label)...
#   3️⃣ Aplicando normalização (standard)...
# ✅ Pipeline FEATURES concluído! Shape final: (5, 4)
#    Novas colunas criadas: 1
# _________ TestValidacaoArtefatos.test_artefatos_normalizacao_criados __________
# ..\tests\integration\test_cenarios_reais.py:198: in test_artefatos_normalizacao_criados
#     assert 'artefatos_normalizacao' in artefatos
# E   AssertionError: assert 'artefatos_normalizacao' in {'colunas_normalizadas': ['valor1_norm', 'valor2_norm'], 'mapeamentos_codificacao': {}}
# ---------------------------- Captured stdout call -----------------------------
# 🔄 Iniciando pipeline de processamento BASE...
#   1️⃣ Aplicando substituições de limpeza...
#   2️⃣ Convertendo tipos de dados...
#   3️⃣ Imputando valores faltantes...
#   4️⃣ Criando agrupamento temporal...
# ✅ Pipeline BASE concluído! Shape final: (5, 3)
# 🎨 Iniciando pipeline de FEATURES...
#   2️⃣ Aplicando codificação (label)...
#   3️⃣ Aplicando normalização (standard)...
# ✅ Pipeline FEATURES concluído! Shape final: (5, 5)
#    Novas colunas criadas: 2
# _____ TestComparacaoClassificacaoRegressao.test_mesmo_dataset_ambos_tipos _____
# ..\tests\integration\test_cenarios_reais.py:222: in test_mesmo_dataset_ambos_tipos
#     resultado_clf = treinar_rapido(
# E   TypeError: treinar_rapido() got an unexpected keyword argument 'params_setup'
# ---------------------------- Captured stdout call -----------------------------
# 🔄 Iniciando pipeline de processamento BASE...
#   1️⃣ Aplicando substituições de limpeza...
#   2️⃣ Convertendo tipos de dados...
#   3️⃣ Imputando valores faltantes...
#   4️⃣ Criando agrupamento temporal...
# ✅ Pipeline BASE concluído! Shape final: (50, 5)
# _____ TestFluxoCompletoClassificacao.test_pipeline_completo_classificacao _____
# ..\tests\integration\test_pipeline_end_to_end.py:78: in test_pipeline_completo_classificacao
#     assert 'imc' in df_features.columns  # Feature derivada
# E   AssertionError: assert 'imc' in Index(['idade', 'sexo', 'peso', 'altura', 'tmedia', 'ur', 'vel_vento',\n       'target_classe', 'target_valor', 'feature_missing', 'IMC', 'sexo_cod',\n       'idade_norm', 'peso_norm', 'altura_norm', 'tmedia_norm', 'ur_norm',\n       'vel_vento_norm', 'target_classe_norm', 'target_valor_norm',\n       'feature_missing_norm', 'IMC_norm', 'sexo_cod_norm'],\n      dtype='object')
# E    +  where Index(['idade', 'sexo', 'peso', 'altura', 'tmedia', 'ur', 'vel_vento',\n       'target_classe', 'target_valor', 'feature_missing', 'IMC', 'sexo_cod',\n       'idade_norm', 'peso_norm', 'altura_norm', 'tmedia_norm', 'ur_norm',\n       'vel_vento_norm', 'target_classe_norm', 'target_valor_norm',\n       'feature_missing_norm', 'IMC_norm', 'sexo_cod_norm'],\n      dtype='object') =     idade sexo       peso  ...  feature_missing_norm  IMC_norm  sexo_cod_norm\n0      56    m  70.825497  ...              0.000000 -0.123165      -0.816497\n1      69    m  94.164013  ...             -1.791019  0.365722      -0.816497\n2      46    m  66.217251  ...             -1.754468 -1.001666      -0.816497\n3      32    m  56.104398  ...             -1.717916 -0.906148      -0.816497\n4      60    m  67.814892  ...             -1.681365 -0.629017      -0.816497\n..    ...  ...        ...  ...                   ...       ...            ...\n95     42    f  99.722873  ...              1.644813  2.169628       1.224745\n96     62    f  58.796263  ...              1.681365 -0.298711       1.224745\n97     58    f  50.903768  ...              1.717916 -1.403825       1.224745\n98     46    f  74.694686  ...              1.754468 -0.516402       1.224745\n99     32    f  58.941135  ...              1.791019 -0.240093       1.224745\n\n[100 rows x 23 columns].columns
# ---------------------------- Captured stdout call -----------------------------
# 🔄 Iniciando pipeline de processamento BASE...
#   1️⃣ Aplicando substituições de limpeza...
#   2️⃣ Convertendo tipos de dados...
#   3️⃣ Imputando valores faltantes...
# ✅ Pipeline BASE concluído! Shape final: (100, 10)
# 🎨 Iniciando pipeline de FEATURES...
#   1️⃣ Criando features derivadas (1 tipos)...
#   2️⃣ Aplicando codificação (label)...
#   3️⃣ Aplicando normalização (standard)...
# ✅ Pipeline FEATURES concluído! Shape final: (100, 23)
#    Novas colunas criadas: 13
# _________ TestFluxoCompletoRegressao.test_pipeline_completo_regressao _________
# ..\tests\integration\test_pipeline_end_to_end.py:131: in test_pipeline_completo_regressao
#     resultado = treinar_rapido(
# E   TypeError: treinar_rapido() got an unexpected keyword argument 'params_setup'
# ---------------------------- Captured stdout call -----------------------------
# 🔄 Iniciando pipeline de processamento BASE...
#   1️⃣ Aplicando substituições de limpeza...
#   2️⃣ Convertendo tipos de dados...
#   3️⃣ Imputando valores faltantes...
# ✅ Pipeline BASE concluído! Shape final: (100, 10)
# 🎨 Iniciando pipeline de FEATURES...
#   2️⃣ Aplicando codificação (label)...
# ✅ Pipeline FEATURES concluído! Shape final: (100, 11)
#    Novas colunas criadas: 1
# __ TestFluxoCompletoComOtimizacao.test_pipeline_com_otimizacao_classificacao __
# ..\tests\integration\test_pipeline_end_to_end.py:169: in test_pipeline_com_otimizacao_classificacao
#     df_treino = df_features[features_treino + ['target_classe']].dropna()
# ..\.venv\Lib\site-packages\pandas\core\frame.py:3899: in __getitem__
#     indexer = self.columns._get_indexer_strict(key, "columns")[1]
# ..\.venv\Lib\site-packages\pandas\core\indexes\base.py:6115: in _get_indexer_strict
#     self._raise_if_missing(keyarr, indexer, axis_name)
# ..\.venv\Lib\site-packages\pandas\core\indexes\base.py:6179: in _raise_if_missing
#     raise KeyError(f"{not_found} not in index")
# E   KeyError: "['imc'] not in index"
# ---------------------------- Captured stdout call -----------------------------
# 🔄 Iniciando pipeline de processamento BASE...
#   1️⃣ Aplicando substituições de limpeza...
#   2️⃣ Convertendo tipos de dados...
#   3️⃣ Imputando valores faltantes...
# ✅ Pipeline BASE concluído! Shape final: (100, 10)
# 🎨 Iniciando pipeline de FEATURES...
#   1️⃣ Criando features derivadas (1 tipos)...
#   2️⃣ Aplicando codificação (label)...
# ✅ Pipeline FEATURES concluído! Shape final: (100, 12)
#    Novas colunas criadas: 2
# - generated xml file: c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\notebooks\relatorios\test_results.xml -
#
# ---------- coverage: platform win32, python 3.11.0-final-0 -----------
# Name                                                                                                                Stmts   Miss  Cover   Missing
# -------------------------------------------------------------------------------------------------------------------------------------------------
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\features\__init__.py                                              4      0   100%
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\features\codificacao\__init__.py                                  3      0   100%
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\features\codificacao\aplicar_codificacao_rotulos.py              14      0   100%
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\features\codificacao\aplicar_dummy.py                             7      4    43%   15-18
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\features\codificacao\codificar_label.py                           8      0   100%
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\features\criacao_features\__init__.py                             7      0   100%
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\features\criacao_features\adicionar_features_derivadas.py        27      5    81%   19, 26, 42, 44, 50
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\features\criacao_features\calcular_heat_index.py                  6      1    83%   10
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\features\criacao_features\calcular_ponto_orvalho.py               6      1    83%   10
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\features\criacao_features\calcular_tu_stull.py                    6      3    50%   10-12
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\features\criacao_features\calcular_valor_imc.py                   7      1    86%   10
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\features\criacao_features\imc_classe.py                          16     13    19%   9-21
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\features\normalizacao\__init__.py                                 3      0   100%
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\features\normalizacao\definir_escalar.py                          6      0   100%
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\features\normalizacao\normalizar.py                              37     16    57%   36-40, 46, 71-82
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\pipelines\__init__.py                                             5      0   100%
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\pipelines\pipeline_completo.py                                   19     13    32%   49-94
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\pipelines\pipeline_features.py                                   33      3    91%   94-96
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\pipelines\pipeline_processamento.py                              47      0   100%
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\pipelines\pipeline_treinamento_unified.py                        76     18    76%   169-185, 191-203, 209-217
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\processamento\__init__.py                                         4      0   100%
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\processamento\imputacao\__init__.py                               5      0   100%
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\processamento\imputacao\imputar_categoricos.py                   13      3    77%   14, 22-24
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\processamento\imputacao\imputar_media_movel_interpolada.py        9      1    89%   31
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\processamento\imputacao\imputar_numericos.py                     14      3    79%   11, 16, 20
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\processamento\imputacao\imputar_por_coluna.py                    41     20    51%   47, 54, 56, 58-61, 63, 65, 70, 80-92
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\processamento\limpeza\__init__.py                                 5      0   100%
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\processamento\limpeza\aplicar_substituicoes.py                    6      1    83%   11
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\processamento\limpeza\converter_colunas_categoricas.py           10      1    90%   11
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\processamento\limpeza\converter_colunas_float.py                 13      1    92%   20
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\processamento\limpeza\converter_colunas_int.py                   10      1    90%   11
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\processamento\temporal\__init__.py                                4      0   100%
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\processamento\temporal\adicionar_mes_ano.py                       8      0   100%
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\processamento\temporal\converter_colunas_temporais.py             8      0   100%
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\processamento\temporal\garantir_agrupamento_temporal.py           8      1    88%   12
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\treinamento\__init__.py                                           9      0   100%
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\treinamento\avaliacao\__init__.py                                 4      0   100%
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\treinamento\avaliacao\avaliar_modelo.py                          26     20    23%   43-86
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\treinamento\avaliacao\classificar_metricas.py                    12      1    92%   31
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\treinamento\avaliacao\fazer_predicoes.py                          9      4    56%   28-33
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\treinamento\configuracao\__init__.py                              4      0   100%
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\treinamento\configuracao\configurar_parametros.py                26     21    19%   70-102, 118-128, 156-193
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\treinamento\configuracao\criar_experimento.py                    23      1    96%   35
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\treinamento\configuracao\criar_experimento_classificacao.py      15      9    40%   26-41
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\treinamento\persistencia\__init__.py                              3      0   100%
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\treinamento\persistencia\carregar_modelo.py                      10      6    40%   20-28
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\treinamento\persistencia\salvar_modelo.py                        12      7    42%   28-40
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\treinamento\treino\__init__.py                                    4      0   100%
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\treinamento\treino\finalizar_modelo_unified.py                   10      5    50%   31-37
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\treinamento\treino\otimizar_modelo_unified.py                    17     10    41%   35-59
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\treinamento\treino\treinar_modelo_base_unified.py                14      0   100%
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\treinamento\utils\__init__.py                                     4      0   100%
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\treinamento\utils\extrair_estimador.py                            7      5    29%   29-34
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\treinamento\utils\extrair_importancia_features.py                15     11    27%   32-57
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\treinamento\utils\extrair_info_modelo.py                         20     17    15%   22-45
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\treinamento\visualizacao\__init__.py                              2      0   100%
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\treinamento\visualizacao\salvar_plots_modelo.py                  32     26    19%   35-80
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\utils\__init__.py                                                 0      0   100%
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\utils\io\__init__.py                                              2      0   100%
# C:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\src\utils\io\io_local.py                                             80     55    31%   22-23, 28-57, 68-71, 80-85, 93-102, 107-120
# -------------------------------------------------------------------------------------------------------------------------------------------------
# TOTAL                                                                                                                 855    308    64%
# Coverage HTML written to dir relatorios/htmlcov
# Coverage XML written to file relatorios/coverage.xml
#
# =========================== short test summary info ===========================
# FAILED ..\tests\integration\test_cenarios_reais.py::TestCenarioRealConfortoTermico::test_pipeline_com_dados_reais_subset - AssertionError: assert 'imc' in Index(['data', 'hora', 'idade', 'sexo', 'pe...
# FAILED ..\tests\integration\test_cenarios_reais.py::TestValidacaoArtefatos::test_artefatos_codificacao_criados - AssertionError: assert 'artefatos_codificacao' in {'colunas_normalizadas': ...
# FAILED ..\tests\integration\test_cenarios_reais.py::TestValidacaoArtefatos::test_artefatos_normalizacao_criados - AssertionError: assert 'artefatos_normalizacao' in {'colunas_normalizadas':...
# FAILED ..\tests\integration\test_cenarios_reais.py::TestComparacaoClassificacaoRegressao::test_mesmo_dataset_ambos_tipos - TypeError: treinar_rapido() got an unexpected keyword argument 'params_setup'
# FAILED ..\tests\integration\test_pipeline_end_to_end.py::TestFluxoCompletoClassificacao::test_pipeline_completo_classificacao - AssertionError: assert 'imc' in Index(['idade', 'sexo', 'peso', 'altura', '...
# FAILED ..\tests\integration\test_pipeline_end_to_end.py::TestFluxoCompletoRegressao::test_pipeline_completo_regressao - TypeError: treinar_rapido() got an unexpected keyword argument 'params_setup'
# FAILED ..\tests\integration\test_pipeline_end_to_end.py::TestFluxoCompletoComOtimizacao::test_pipeline_com_otimizacao_classificacao - KeyError: "['imc'] not in index"
# ======== 7 failed, 5 passed, 4 skipped, 1 warning in 75.30s (0:01:15) =========
# CPU times: total: 31.2 ms
# Wall time: 1min 18s

# %% [markdown]
# ## 🎯 Executar Testes de Módulos Específicos
#
# ### Testes de Features

# %%
# Testa módulo de features (codificação, normalização, criação)
tests_path = str(PROJECT_ROOT / 'tests' / 'unit' / 'features')
# !python -m pytest "{tests_path}" -v
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### Testes de Treinamento

# %%
# Testa módulo de treinamento
tests_path = str(PROJECT_ROOT / 'tests' / 'unit' / 'treinamento')
# !python -m pytest "{tests_path}" -v

# %% [markdown]
# ### Testes de Pipelines

# %%
# Testa pipelines (processamento, features, treinamento)
tests_path = str(PROJECT_ROOT / 'tests' / 'unit' / 'pipelines')
# !python -m pytest "{tests_path}" -v

# %% [markdown]
# ### Testes de Processamento

# %%
# Testa processamento (limpeza, imputação, temporal)
tests_path = str(PROJECT_ROOT / 'tests' / 'unit' / 'processamento')
# !python -m pytest "{tests_path}" -v

# %% [markdown]
# ## 📊 Relatório de Cobertura de Código
#
# Gera relatório HTML mostrando quais linhas de código estão cobertas por testes.

# %%
# %%time
# Cria pasta de relatórios
relatorios_dir = PROJECT_ROOT / 'relatorios'
relatorios_dir.mkdir(exist_ok=True)

# Executa testes com relatório de cobertura
tests_path = str(PROJECT_ROOT / 'tests')
src_path = str(PROJECT_ROOT / 'src')
htmlcov_path = str(relatorios_dir / 'htmlcov')

# !python -m pytest "{tests_path}" --cov="{src_path}" --cov-report=html:"{htmlcov_path}" --cov-report=term

print(f"\n✅ Relatório HTML gerado em: relatorios/htmlcov/index.html")
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.0, pytest-7.4.3, pluggy-1.6.0 -- c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops\.venv\Scripts\python.exe
# cachedir: .pytest_cache
# hypothesis profile 'default' -> database=DirectoryBasedExampleDatabase(WindowsPath('c:/Arquivos_Pessoais/PROJETOS/tcc_mba_esalq_mlops/notebooks/.hypothesis/examples'))
# rootdir: c:\Arquivos_Pessoais\PROJETOS\tcc_mba_esalq_mlops
# configfile: pytest.ini
# plugins: anyio-4.12.1, dash-4.0.0, Faker-20.1.0, hypothesis-6.99.13, asyncio-0.21.1, cov-4.1.0, mock-3.12.0, timeout-2.4.0
# asyncio: mode=Mode.STRICT
# collecting ... collected 298 items / 4 skipped
#
# ..\tests\integration\test_cenarios_reais.py::TestCenarioRealConfortoTermico::test_pipeline_com_dados_reais_subset FAILED [  0%]
# ..\tests\integration\test_cenarios_reais.py::TestCenariosEdgeCases::test_dados_com_muitos_missings PASSED [  0%]
# ..\tests\integration\test_cenarios_reais.py::TestCenariosEdgeCases::test_dados_minimos PASSED [  1%]
# ..\tests\integration\test_cenarios_reais.py::TestCenariosEdgeCases::test_coluna_categorica_valor_unico PASSED [  1%]
# ..\tests\integration\test_cenarios_reais.py::TestValidacaoArtefatos::test_artefatos_codificacao_criados FAILED [  1%]
# ..\tests\integration\test_cenarios_reais.py::TestValidacaoArtefatos::test_artefatos_normalizacao_criados FAILED [  2%]
# ..\tests\integration\test_cenarios_reais.py::TestComparacaoClassificacaoRegressao::test_mesmo_dataset_ambos_tipos FAILED [  2%]
# ..\tests\integration\test_pipeline_end_to_end.py::TestFluxoCompletoClassificacao::test_pipeline_completo_classificacao FAILED [  2%]
# ..\tests\integration\test_pipeline_end_to_end.py::TestFluxoCompletoRegressao::test_pipeline_completo_regressao FAILED [  3%]
# ..\tests\integration\test_pipeline_end_to_end.py::TestFluxoCompletoComOtimizacao::test_pipeline_com_otimizacao_classificacao FAILED [  3%]
# ..\tests\integration\test_pipeline_end_to_end.py::TestConsistenciaDados::test_sem_perda_excessiva_de_dados PASSED [  3%]
# ..\tests\integration\test_pipeline_end_to_end.py::TestConsistenciaDados::test_tipos_colunas_consistentes PASSED [  4%]
# ..\tests\unit\test_features_codificacao.py::TestAplicarCodificacaoRotulos::test_codifica_coluna_categorica PASSED [  4%]
# ..\tests\unit\test_features_codificacao.py::TestAplicarCodificacaoRotulos::test_preserva_coluna_original PASSED [  4%]
# ..\tests\unit\test_features_codificacao.py::TestAplicarDummy::test_cria_colunas_dummy FAILED [  5%]
# ..\tests\unit\test_features_codificacao.py::TestAplicarDummy::test_drop_first FAILED [  5%]
# ..\tests\unit\test_features_criacao.py::TestCalcularValorIMC::test_calcula_imc_correto PASSED [  5%]
# ..\tests\unit\test_features_criacao.py::TestCalcularValorIMC::test_imc_com_nan PASSED [  6%]
# ..\tests\unit\test_features_criacao.py::TestCalcularValorIMC::test_imc_altura_zero PASSED [  6%]
# ..\tests\unit\test_features_criacao.py::TestIMCClasse::test_classificacao_baixo_peso PASSED [  6%]
# ..\tests\unit\test_features_criacao.py::TestIMCClasse::test_classificacao_peso_normal PASSED [  7%]
# ..\tests\unit\test_features_criacao.py::TestIMCClasse::test_classificacao_sobrepeso PASSED [  7%]
# ..\tests\unit\test_features_criacao.py::TestIMCClasse::test_classificacao_obesidade FAILED [  7%]
# ..\tests\unit\test_features_criacao.py::TestCalcularHeatIndex::test_calcula_heat_index_valores_normais PASSED [  8%]
# ..\tests\unit\test_features_criacao.py::TestCalcularPontoOrvalho::test_calcula_ponto_orvalho_valores_normais PASSED [  8%]
# ..\tests\unit\test_features_criacao.py::TestCalcularTUStull::test_multiplica_temperatura_umidade FAILED [  8%]
# ..\tests\unit\test_features_criacao.py::TestAdicionarFeaturesDerivadas::test_adicionar_imc FAILED [  9%]
# ..\tests\unit\test_features_criacao.py::TestAdicionarFeaturesDerivadas::test_adicionar_heat_index PASSED [  9%]
# ..\tests\unit\test_features_criacao.py::TestAdicionarFeaturesDerivadas::test_adicionar_multiplas_features FAILED [  9%]
# ..\tests\unit\test_features_normalizacao.py::TestPickScaler::test_retorna_standard_scaler PASSED [ 10%]
# ..\tests\unit\test_features_normalizacao.py::TestPickScaler::test_retorna_minmax_scaler PASSED [ 10%]
# ..\tests\unit\test_features_normalizacao.py::TestPickScaler::test_retorna_robust_scaler PASSED [ 10%]
# ..\tests\unit\test_features_normalizacao.py::TestPickScaler::test_levanta_erro_metodo_invalido FAILED [ 11%]
# ..\tests\unit\test_features_normalizacao.py::TestNormalizar::test_normaliza_com_standard FAILED [ 11%]
# ..\tests\unit\test_features_normalizacao.py::TestNormalizar::test_normaliza_com_minmax FAILED [ 11%]
# ..\tests\unit\test_features_normalizacao.py::TestNormalizar::test_preserva_colunas_nao_normalizadas FAILED [ 12%]
# ..\tests\unit\test_features_normalizacao.py::TestNormalizar::test_normaliza_por_agrupamento FAILED [ 12%]
# ..\tests\unit\api\test_app.py::TestAPIConfortoTermico::test_health_check ERROR [ 12%]
# ..\tests\unit\api\test_app.py::TestAPIConfortoTermico::test_predicao_dados_validos ERROR [ 13%]
# ..\tests\unit\api\test_app.py::TestAPIConfortoTermico::test_predicao_dados_invalidos ERROR [ 13%]
# ..\tests\unit\api\test_app.py::TestAPIConfortoTermico::test_predicao_valores_extremos ERROR [ 13%]
# ..\tests\unit\api\test_app.py::TestAPIConfortoTermico::test_predicao_tipos_incorretos ERROR [ 14%]
# ..\tests\unit\api\test_app.py::TestAPIConfortoTermico::test_endpoint_inexistente ERROR [ 14%]
# ..\tests\unit\api\test_app.py::TestAPIConfortoTermico::test_metodo_nao_permitido ERROR [ 14%]
# ..\tests\unit\features\codificacao\test_aplicar_codificacao_rotulos.py::TestAplicarCodificacaoLabel::test_codificacao_multiplas_colunas FAILED [ 15%]
# ..\tests\unit\features\codificacao\test_aplicar_codificacao_rotulos.py::TestAplicarCodificacaoLabel::test_colunas_inexistentes_ignoradas FAILED [ 15%]
# ..\tests\unit\features\codificacao\test_aplicar_codificacao_rotulos.py::TestAplicarCodificacaoLabel::test_sufixo_personalizado FAILED [ 15%]
# ..\tests\unit\features\codificacao\test_aplicar_codificacao_rotulos.py::TestAplicarCodificacaoLabel::test_dataframe_original_nao_modificado FAILED [ 16%]
# ..\tests\unit\features\codificacao\test_aplicar_dummy.py::test_aplicar_dummy_basico PASSED [ 16%]
# ..\tests\unit\features\codificacao\test_aplicar_dummy.py::test_aplicar_dummy_multiplas_colunas PASSED [ 16%]
# ..\tests\unit\features\codificacao\test_aplicar_dummy.py::test_aplicar_dummy_drop_first PASSED [ 17%]
# ..\tests\unit\features\codificacao\test_aplicar_dummy.py::test_aplicar_dummy_valores_binarios PASSED [ 17%]
# ..\tests\unit\features\codificacao\test_aplicar_one_hot.py::TestAplicarOneHot::test_one_hot_basico FAILED [ 17%]
# ..\tests\unit\features\codificacao\test_aplicar_one_hot.py::TestAplicarOneHot::test_drop_first FAILED [ 18%]
# ..\tests\unit\features\codificacao\test_aplicar_one_hot.py::TestAplicarOneHot::test_colunas_vazias FAILED [ 18%]
# ..\tests\unit\features\codificacao\test_codificar_label.py::TestCodificarLabel::test_codificacao_basica FAILED [ 18%]
# ..\tests\unit\features\codificacao\test_codificar_label.py::TestCodificarLabel::test_valores_faltantes FAILED [ 19%]
# ..\tests\unit\features\codificacao\test_codificar_label.py::TestCodificarLabel::test_mapeamento_reverso FAILED [ 19%]
# ..\tests\unit\features\criacao_features\test_adicionar_features_derivadas.py::TestAdicionarFeaturesDerivadas::test_adicionar_imc PASSED [ 19%]
# ..\tests\unit\features\criacao_features\test_adicionar_features_derivadas.py::TestAdicionarFeaturesDerivadas::test_adicionar_heat_index FAILED [ 20%]
# ..\tests\unit\features\criacao_features\test_adicionar_features_derivadas.py::TestAdicionarFeaturesDerivadas::test_multiplas_features FAILED [ 20%]
# ..\tests\unit\features\criacao_features\test_adicionar_features_derivadas.py::TestAdicionarFeaturesDerivadas::test_lista_vazia FAILED [ 20%]
# ..\tests\unit\features\criacao_features\test_calcular_heat_index.py::TestCalcularHeatIndex::test_heat_index_valores_normais PASSED [ 21%]
# ..\tests\unit\features\criacao_features\test_calcular_heat_index.py::TestCalcularHeatIndex::test_heat_index_valores_nulos FAILED [ 21%]
# ..\tests\unit\features\criacao_features\test_calcular_heat_index.py::TestCalcularHeatIndex::test_heat_index_aumenta_com_umidade FAILED [ 21%]
# ..\tests\unit\features\criacao_features\test_calcular_ponto_orvalho.py::TestCalcularPontoOrvalho::test_ponto_orvalho_basico PASSED [ 22%]
# ..\tests\unit\features\criacao_features\test_calcular_ponto_orvalho.py::TestCalcularPontoOrvalho::test_ponto_orvalho_menor_que_temperatura FAILED [ 22%]
# ..\tests\unit\features\criacao_features\test_calcular_ponto_orvalho.py::TestCalcularPontoOrvalho::test_valores_nulos FAILED [ 22%]
# ..\tests\unit\features\criacao_features\test_calcular_tu_stull.py::test_calcular_tu_stull FAILED [ 23%]
# ..\tests\unit\features\criacao_features\test_calcular_valor_imc.py::TestCalcularIMC::test_calculo_imc_normal PASSED [ 23%]
# ..\tests\unit\features\criacao_features\test_calcular_valor_imc.py::TestCalcularIMC::test_imc_valores_nulos FAILED [ 23%]
# ..\tests\unit\features\criacao_features\test_calcular_valor_imc.py::TestCalcularIMC::test_altura_zero FAILED [ 24%]
# ..\tests\unit\features\criacao_features\test_calcular_valor_imc.py::TestCalcularIMC::test_imc_diferentes_pesos FAILED [ 24%]
# ..\tests\unit\features\criacao_features\test_imc_classe.py::TestIMCClasse::test_abaixo_do_peso PASSED [ 24%]
# ..\tests\unit\features\criacao_features\test_imc_classe.py::TestIMCClasse::test_peso_normal PASSED [ 25%]
# ..\tests\unit\features\criacao_features\test_imc_classe.py::TestIMCClasse::test_sobrepeso PASSED [ 25%]
# ..\tests\unit\features\criacao_features\test_imc_classe.py::TestIMCClasse::test_obesidade_graus FAILED [ 25%]
# ..\tests\unit\features\criacao_features\test_imc_classe.py::TestIMCClasse::test_valor_nulo FAILED [ 26%]
# ..\tests\unit\features\normalizacao\test_definir_escalar.py::test_pick_scaler_standard PASSED [ 26%]
# ..\tests\unit\features\normalizacao\test_definir_escalar.py::test_pick_scaler_minmax PASSED [ 26%]
# ..\tests\unit\features\normalizacao\test_definir_escalar.py::test_pick_scaler_robust PASSED [ 27%]
# ..\tests\unit\features\normalizacao\test_definir_escalar.py::test_pick_scaler_invalid FAILED [ 27%]
# ..\tests\unit\features\normalizacao\test_normalizar.py::test_normalizar_sem_agrupamento FAILED [ 27%]
# ..\tests\unit\features\normalizacao\test_normalizar.py::test_normalizar_com_agrupamento FAILED [ 28%]
# ..\tests\unit\pipelines\test_pipeline_completo.py::test_pipeline_completo_mock FAILED [ 28%]
# ..\tests\unit\pipelines\test_pipeline_features.py::TestPipelineFeatures::test_pipeline_basico PASSED [ 28%]
# ..\tests\unit\pipelines\test_pipeline_features.py::TestPipelineFeatures::test_codificacao_label PASSED [ 29%]
# ..\tests\unit\pipelines\test_pipeline_features.py::TestPipelineFeatures::test_codificacao_onehot PASSED [ 29%]
# ..\tests\unit\pipelines\test_pipeline_features.py::TestPipelineFeatures::test_normalizacao_todas_colunas PASSED [ 29%]
# ..\tests\unit\pipelines\test_pipeline_features.py::TestPipelineFeatures::test_normalizacao_colunas_especificas PASSED [ 30%]
# ..\tests\unit\pipelines\test_pipeline_features.py::TestPipelineFeatures::test_features_derivadas FAILED [ 30%]
# ..\tests\unit\pipelines\test_pipeline_features.py::TestPipelineFeatures::test_pipeline_completo FAILED [ 30%]
# ..\tests\unit\pipelines\test_pipeline_features.py::TestPipelineFeatures::test_ordem_operacoes FAILED [ 31%]
# ..\tests\unit\pipelines\test_pipeline_features.py::TestPipelineFeatures::test_preserva_original PASSED [ 31%]
# ..\tests\unit\pipelines\test_pipeline_features.py::TestPipelineFeatures::test_colunas_inexistentes PASSED [ 31%]
# ..\tests\unit\pipelines\test_pipeline_processamento.py::test_pipeline_processamento_basico PASSED [ 32%]
# ..\tests\unit\pipelines\test_pipeline_processamento.py::test_pipeline_padroniza_nomes_colunas PASSED [ 32%]
# ..\tests\unit\pipelines\test_pipeline_processamento.py::test_pipeline_conversao_tipos FAILED [ 32%]
# ..\tests\unit\pipelines\test_pipeline_processamento.py::test_pipeline_substituicoes PASSED [ 33%]
# ..\tests\unit\pipelines\test_pipeline_processamento.py::test_pipeline_imputacao_numerica PASSED [ 33%]
# ..\tests\unit\pipelines\test_pipeline_processamento.py::test_pipeline_imputacao_categorica PASSED [ 33%]
# ..\tests\unit\pipelines\test_pipeline_processamento.py::test_pipeline_imputacao_customizada PASSED [ 34%]
# ..\tests\unit\pipelines\test_pipeline_processamento.py::test_pipeline_agrupamento_temporal PASSED [ 34%]
# ..\tests\unit\pipelines\test_pipeline_processamento.py::test_pipeline_sem_agrupamento_temporal PASSED [ 34%]
# ..\tests\unit\pipelines\test_pipeline_processamento.py::test_pipeline_nao_modifica_original PASSED [ 35%]
# ..\tests\unit\pipelines\test_pipeline_processamento.py::test_pipeline_shape_preservado PASSED [ 35%]
# ..\tests\unit\pipelines\test_pipeline_processamento.py::test_pipeline_com_dataframe_vazio PASSED [ 35%]
# ..\tests\unit\pipelines\test_pipeline_processamento.py::test_pipeline_parametros_defaults PASSED [ 36%]
# ..\tests\unit\pipelines\test_pipeline_treinamento_unified.py::test_treinar_pipeline_completo_classificacao FAILED [ 36%]
# ..\tests\unit\pipelines\test_pipeline_treinamento_unified.py::test_treinar_pipeline_completo_regressao FAILED [ 36%]
# ..\tests\unit\pipelines\test_pipeline_treinamento_unified.py::test_treinar_rapido FAILED [ 37%]
# ..\tests\unit\processamento\test_imputacao.py::TestImputarNumericos::test_imputa_com_media FAILED [ 37%]
# ..\tests\unit\processamento\test_imputacao.py::TestImputarNumericos::test_imputa_com_mediana FAILED [ 37%]
# ..\tests\unit\processamento\test_imputacao.py::TestImputarNumericos::test_imputa_com_constante FAILED [ 38%]
# ..\tests\unit\processamento\test_imputacao.py::TestImputarCategoricos::test_imputa_com_moda FAILED [ 38%]
# ..\tests\unit\processamento\test_imputacao.py::TestImputarCategoricos::test_imputa_com_constante FAILED [ 38%]
# ..\tests\unit\processamento\test_imputacao.py::TestImputarPorColuna::test_imputa_diferentes_metodos FAILED [ 39%]
# ..\tests\unit\processamento\test_imputacao.py::TestImputarMediaMovelInterpolada::test_imputa_com_janela FAILED [ 39%]
# ..\tests\unit\processamento\test_imputacao.py::TestImputarMediaMovelInterpolada::test_preserva_valores_existentes FAILED [ 39%]
# ..\tests\unit\processamento\test_imputacao_geral.py::TestImputarNumericos::test_imputacao_media FAILED [ 40%]
# ..\tests\unit\processamento\test_imputacao_geral.py::TestImputarNumericos::test_imputacao_mediana FAILED [ 40%]
# ..\tests\unit\processamento\test_imputacao_geral.py::TestImputarNumericos::test_imputacao_constante FAILED [ 40%]
# ..\tests\unit\processamento\test_imputacao_geral.py::TestImputarCategoricos::test_imputacao_moda FAILED [ 41%]
# ..\tests\unit\processamento\test_imputacao_geral.py::TestImputarCategoricos::test_imputacao_constante FAILED [ 41%]
# ..\tests\unit\processamento\test_limpeza.py::TestAplicarSubstituicoes::test_substitui_valores_simples PASSED [ 41%]
# ..\tests\unit\processamento\test_limpeza.py::TestAplicarSubstituicoes::test_substitui_multiplos_valores PASSED [ 42%]
# ..\tests\unit\processamento\test_limpeza.py::TestAplicarSubstituicoes::test_nao_modifica_sem_substituicoes PASSED [ 42%]
# ..\tests\unit\processamento\test_limpeza.py::TestConverterColunasCategoricas::test_converte_para_string PASSED [ 42%]
# ..\tests\unit\processamento\test_limpeza.py::TestConverterColunasCategoricas::test_converte_multiplas_colunas PASSED [ 43%]
# ..\tests\unit\processamento\test_limpeza.py::TestConverterColunasCategoricas::test_ignora_coluna_inexistente PASSED [ 43%]
# ..\tests\unit\processamento\test_limpeza.py::TestConverterColunasFloat::test_converte_para_float PASSED [ 43%]
# ..\tests\unit\processamento\test_limpeza.py::TestConverterColunasFloat::test_converte_com_valores_nulos PASSED [ 44%]
# ..\tests\unit\processamento\test_limpeza.py::TestConverterColunasInt::test_converte_para_int PASSED [ 44%]
# ..\tests\unit\processamento\test_limpeza.py::TestConverterColunasInt::test_converte_com_valores_nulos PASSED [ 44%]
# ..\tests\unit\processamento\test_limpeza_geral.py::TestAplicarSubstituicoes::test_substitui_valores_simples PASSED [ 45%]
# ..\tests\unit\processamento\test_limpeza_geral.py::TestAplicarSubstituicoes::test_substitui_multiplos_valores PASSED [ 45%]
# ..\tests\unit\processamento\test_limpeza_geral.py::TestConverterColunasFloat::test_converte_string_para_float PASSED [ 45%]
# ..\tests\unit\processamento\test_limpeza_geral.py::TestConverterColunasFloat::test_mantém_valores_numericos PASSED [ 46%]
# ..\tests\unit\processamento\test_limpeza_geral.py::TestConverterColunasInt::test_converte_string_para_int PASSED [ 46%]
# ..\tests\unit\processamento\test_limpeza_geral.py::TestConverterColunasInt::test_converte_float_para_int PASSED [ 46%]
# ..\tests\unit\processamento\test_limpeza_geral.py::TestConverterColunasCategoricas::test_converte_para_string PASSED [ 47%]
# ..\tests\unit\processamento\test_limpeza_geral.py::TestConverterColunasCategoricas::test_preserva_valores PASSED [ 47%]
# ..\tests\unit\processamento\test_temporal.py::TestAdicionarMesAno::test_cria_mes_ano PASSED [ 47%]
# ..\tests\unit\processamento\test_temporal.py::TestAdicionarMesAno::test_com_dados_validos PASSED [ 48%]
# ..\tests\unit\processamento\test_temporal.py::TestConverterColunasTemporais::test_converte_string_para_datetime FAILED [ 48%]
# ..\tests\unit\processamento\test_temporal.py::TestConverterColunasTemporais::test_mantém_dados_validos FAILED [ 48%]
# ..\tests\unit\processamento\test_temporal.py::TestGarantirAgrupamentoTemporal::test_cria_agrupamento_se_necessario PASSED [ 49%]
# ..\tests\unit\processamento\test_utils.py::TestCalcularValorIMC::test_calculo_basico PASSED [ 49%]
# ..\tests\unit\processamento\test_utils.py::TestCalcularValorIMC::test_valores_nulos FAILED [ 50%]
# ..\tests\unit\processamento\test_utils.py::TestCalcularValorIMC::test_valores_invalidos_viram_nan FAILED [ 50%]
# ..\tests\unit\processamento\test_utils.py::TestCalcularIMC::test_calculo_imc_normal FAILED [ 50%]
# ..\tests\unit\processamento\test_utils.py::TestCalcularIMC::test_calculo_imc_valores_extremos FAILED [ 51%]
# ..\tests\unit\processamento\test_utils.py::TestCalcularIMC::test_imc_valores_nulos FAILED [ 51%]
# ..\tests\unit\processamento\test_utils.py::TestCalcularIMC::test_imc_altura_zero FAILED [ 51%]
# ..\tests\unit\processamento\test_utils.py::TestIMCClasse::test_classificacao_imc_todas_categorias FAILED [ 52%]
# ..\tests\unit\processamento\test_utils.py::TestIMCClasse::test_classificacao_imc_limites FAILED [ 52%]
# ..\tests\unit\processamento\test_utils.py::TestCalcularIndiceCalor::test_indice_calor_condicoes_normais FAILED [ 52%]
# ..\tests\unit\processamento\test_utils.py::TestCalcularIndiceCalor::test_indice_calor_temperatura_baixa FAILED [ 53%]
# ..\tests\unit\processamento\test_utils.py::TestCalcularIndiceCalor::test_indice_calor_valores_nulos FAILED [ 53%]
# ..\tests\unit\processamento\test_utils.py::TestCalcularPontoOrvalho::test_ponto_orvalho_calculo_basico FAILED [ 53%]
# ..\tests\unit\processamento\test_utils.py::TestCalcularPontoOrvalho::test_ponto_orvalho_umidade_alta FAILED [ 54%]
# ..\tests\unit\processamento\test_utils.py::TestCalcularPontoOrvalho::test_ponto_orvalho_valores_nulos FAILED [ 54%]
# ..\tests\unit\processamento\test_utils.py::TestCodificarComLabels::test_codificacao_basica FAILED [ 54%]
# ..\tests\unit\processamento\test_utils.py::TestCodificarComLabels::test_codificacao_com_nulos FAILED [ 55%]
# ..\tests\unit\processamento\test_utils.py::TestCodificarComLabels::test_codificacao_serie_vazia FAILED [ 55%]
# ..\tests\unit\processamento\imputacao\test_imputar_categoricos.py::TestImputarCategoricos::test_imputacao_moda FAILED [ 55%]
# ..\tests\unit\processamento\imputacao\test_imputar_categoricos.py::TestImputarCategoricos::test_imputacao_constante FAILED [ 56%]
# ..\tests\unit\processamento\imputacao\test_imputar_categoricos.py::TestImputarCategoricos::test_preserva_nao_categoricos PASSED [ 56%]
# ..\tests\unit\processamento\imputacao\test_imputar_media_movel_interpolada.py::TestImputarMediaMovelInterpolada::test_media_movel_basica FAILED [ 56%]
# ..\tests\unit\processamento\imputacao\test_imputar_media_movel_interpolada.py::TestImputarMediaMovelInterpolada::test_interpolacao_linear FAILED [ 57%]
# ..\tests\unit\processamento\imputacao\test_imputar_media_movel_interpolada.py::TestImputarMediaMovelInterpolada::test_window_grande FAILED [ 57%]
# ..\tests\unit\processamento\imputacao\test_imputar_media_movel_interpolada.py::TestImputarMediaMovelInterpolada::test_multiplos_valores_consecutivos_faltantes FAILED [ 57%]
# ..\tests\unit\processamento\imputacao\test_imputar_media_movel_interpolada.py::TestImputarMediaMovelInterpolada::test_coluna_inexistente PASSED [ 58%]
# ..\tests\unit\processamento\imputacao\test_imputar_media_movel_interpolada.py::TestImputarMediaMovelInterpolada::test_coluna_sem_valores_faltantes PASSED [ 58%]
# ..\tests\unit\processamento\imputacao\test_imputar_media_movel_interpolada.py::TestImputarMediaMovelInterpolada::test_primeiro_valor_faltante FAILED [ 58%]
# ..\tests\unit\processamento\imputacao\test_imputar_media_movel_interpolada.py::TestImputarMediaMovelInterpolada::test_ultimo_valor_faltante PASSED [ 59%]
# ..\tests\unit\processamento\imputacao\test_imputar_media_movel_interpolada.py::TestImputarMediaMovelInterpolada::test_todos_valores_faltantes PASSED [ 59%]
# ..\tests\unit\processamento\imputacao\test_imputar_media_movel_interpolada.py::TestImputarMediaMovelInterpolada::test_window_min_periods PASSED [ 59%]
# ..\tests\unit\processamento\imputacao\test_imputar_numericos.py::TestImputarNumericos::test_imputacao_media PASSED [ 60%]
# ..\tests\unit\processamento\imputacao\test_imputar_numericos.py::TestImputarNumericos::test_imputacao_mediana PASSED [ 60%]
# ..\tests\unit\processamento\imputacao\test_imputar_numericos.py::TestImputarNumericos::test_sem_valores_faltantes PASSED [ 60%]
# ..\tests\unit\processamento\imputacao\test_imputar_por_coluna.py::TestImputarPorColuna::test_imputacao_median_coluna_especifica FAILED [ 61%]
# ..\tests\unit\processamento\imputacao\test_imputar_por_coluna.py::TestImputarPorColuna::test_imputacao_mode_coluna_categorica PASSED [ 61%]
# ..\tests\unit\processamento\imputacao\test_imputar_por_coluna.py::TestImputarPorColuna::test_imputacao_backward_fill PASSED [ 61%]
# ..\tests\unit\processamento\imputacao\test_imputar_por_coluna.py::TestImputarPorColuna::test_imputacao_forward_fill PASSED [ 62%]
# ..\tests\unit\processamento\imputacao\test_imputar_por_coluna.py::TestImputarPorColuna::test_imputacao_valor_constante PASSED [ 62%]
# ..\tests\unit\processamento\imputacao\test_imputar_por_coluna.py::TestImputarPorColuna::test_imputacao_valor_numerico_constante PASSED [ 62%]
# ..\tests\unit\processamento\imputacao\test_imputar_por_coluna.py::TestImputarPorColuna::test_imputacao_multiplas_colunas_diferentes_metodos FAILED [ 63%]
# ..\tests\unit\processamento\imputacao\test_imputar_por_coluna.py::TestImputarPorColuna::test_metodo_padrao_para_colunas_nao_especificadas PASSED [ 63%]
# ..\tests\unit\processamento\imputacao\test_imputar_por_coluna.py::TestImputarPorColuna::test_coluna_inexistente_no_config PASSED [ 63%]
# ..\tests\unit\processamento\imputacao\test_imputar_por_coluna.py::TestImputarPorColuna::test_coluna_sem_valores_faltantes PASSED [ 64%]
# ..\tests\unit\processamento\imputacao\test_imputar_por_coluna.py::TestImputarPorColuna::test_config_vazio PASSED [ 64%]
# ..\tests\unit\processamento\limpeza\test_aplicar_substituicoes.py::TestAplicarSubstituicoes::test_substituicoes_basicas PASSED [ 64%]
# ..\tests\unit\processamento\limpeza\test_aplicar_substituicoes.py::TestAplicarSubstituicoes::test_coluna_nao_afetada PASSED [ 65%]
# ..\tests\unit\processamento\limpeza\test_aplicar_substituicoes.py::TestAplicarSubstituicoes::test_dicionario_vazio PASSED [ 65%]
# ..\tests\unit\processamento\limpeza\test_converter_colunas_categoricas.py::test_converter_colunas_categoricas PASSED [ 65%]
# ..\tests\unit\processamento\limpeza\test_converter_colunas_float.py::TestConverterColunasFloat::test_conversao_basica PASSED [ 66%]
# ..\tests\unit\processamento\limpeza\test_converter_colunas_float.py::TestConverterColunasFloat::test_conversao_virgula_decimal PASSED [ 66%]
# ..\tests\unit\processamento\limpeza\test_converter_colunas_float.py::TestConverterColunasFloat::test_valores_invalidos_tornam_nan PASSED [ 66%]
# ..\tests\unit\processamento\limpeza\test_converter_colunas_float.py::TestConverterColunasFloat::test_colunas_inexistentes_ignoradas PASSED [ 67%]
# ..\tests\unit\processamento\limpeza\test_converter_colunas_int.py::test_converter_colunas_int PASSED [ 67%]
# ..\tests\unit\processamento\temporal\test_adicionar_mes_ano.py::test_adicionar_mes_ano FAILED [ 67%]
# ..\tests\unit\processamento\temporal\test_converter_colunas_temporais.py::TestConverterColunasTemporais::test_conversao_data_hora PASSED [ 68%]
# ..\tests\unit\processamento\temporal\test_converter_colunas_temporais.py::TestConverterColunasTemporais::test_formato_brasileiro PASSED [ 68%]
# ..\tests\unit\processamento\temporal\test_converter_colunas_temporais.py::TestConverterColunasTemporais::test_coluna_inexistente PASSED [ 68%]
# ..\tests\unit\processamento\temporal\test_garantir_agrupamento_temporal.py::TestGarantirAgrupamentoTemporal::test_cria_coluna_mes_ano PASSED [ 69%]
# ..\tests\unit\processamento\temporal\test_garantir_agrupamento_temporal.py::TestGarantirAgrupamentoTemporal::test_preserva_coluna_existente PASSED [ 69%]
# ..\tests\unit\treinamento\avaliacao\test_avaliar_modelo.py::TestAvaliarModelo::test_avaliar_modelo_retorna_metricas ERROR [ 69%]
# ..\tests\unit\treinamento\avaliacao\test_avaliar_modelo.py::TestAvaliarModelo::test_metricas_estao_no_intervalo_valido ERROR [ 70%]
# ..\tests\unit\treinamento\avaliacao\test_classificar_metricas.py::test_classificar_metricas_colunas_classificacao PASSED [ 70%]
# ..\tests\unit\treinamento\avaliacao\test_classificar_metricas.py::test_classificar_metricas_ranking_correto PASSED [ 70%]
# ..\tests\unit\treinamento\avaliacao\test_classificar_metricas.py::test_classificar_metricas_ordenado_por_media PASSED [ 71%]
# ..\tests\unit\treinamento\avaliacao\test_classificar_metricas.py::test_classificar_metricas_erro_metrica_inexistente PASSED [ 71%]
# ..\tests\unit\treinamento\avaliacao\test_classificar_metricas.py::test_classificar_metricas_multiplas_metricas PASSED [ 71%]
# ..\tests\unit\treinamento\avaliacao\test_classificar_metricas.py::test_classificar_metricas_nao_modifica_original PASSED [ 72%]
# ..\tests\unit\treinamento\avaliacao\test_fazer_predicoes.py::TestFazerPredicoes::test_predicoes_tem_tamanho_correto ERROR [ 72%]
# ..\tests\unit\treinamento\avaliacao\test_fazer_predicoes.py::TestFazerPredicoes::test_predicoes_sao_validas ERROR [ 72%]
# ..\tests\unit\treinamento\avaliacao\test_fazer_predicoes.py::TestFazerPredicoes::test_predicoes_com_probabilidades ERROR [ 73%]
# ..\tests\unit\treinamento\configuracao\test_configurar_parametros.py::test_configurar_parametros_sem_customizacao PASSED [ 73%]
# ..\tests\unit\treinamento\configuracao\test_configurar_parametros.py::test_configurar_parametros_merge_customizados FAILED [ 73%]
# ..\tests\unit\treinamento\configuracao\test_configurar_parametros.py::test_configurar_parametros_sobrescreve_padrao FAILED [ 74%]
# ..\tests\unit\treinamento\configuracao\test_configurar_parametros.py::test_configurar_parametros_nao_modifica_original PASSED [ 74%]
# ..\tests\unit\treinamento\configuracao\test_criar_experimento.py::test_criar_experimento_classificacao PASSED [ 74%]
# ..\tests\unit\treinamento\configuracao\test_criar_experimento.py::test_criar_experimento_regressao PASSED [ 75%]
# ..\tests\unit\treinamento\configuracao\test_criar_experimento.py::test_criar_experimento_tipo_invalido PASSED [ 75%]
# ..\tests\unit\treinamento\configuracao\test_criar_experimento.py::test_criar_experimento_com_params_customizados PASSED [ 75%]
# ..\tests\unit\treinamento\configuracao\test_criar_experimento.py::test_criar_experimento_coluna_alvo_inexistente PASSED [ 76%]
# ..\tests\unit\treinamento\configuracao\test_criar_experimento_classificacao.py::TestTreinarModeloBase::test_treina_modelo_basico SKIPPED [ 76%]
# ..\tests\unit\treinamento\configuracao\test_criar_experimento_classificacao.py::TestTreinarModeloBase::test_treina_com_parametros SKIPPED [ 76%]
# ..\tests\unit\treinamento\configuracao\test_criar_experimento_classificacao.py::TestOtimizarModelo::test_otimiza_modelo SKIPPED [ 77%]
# ..\tests\unit\treinamento\configuracao\test_criar_experimento_classificacao.py::TestFinalizarModelo::test_finaliza_modelo SKIPPED [ 77%]
# ..\tests\unit\treinamento\configuracao\test_criar_experimento_classificacao.py::TestFazerPredicoes::test_predicoes_basicas SKIPPED [ 77%]
# ..\tests\unit\treinamento\configuracao\test_criar_experimento_classificacao.py::TestAvaliarModelo::test_avalia_modelo SKIPPED [ 78%]
# ..\tests\unit\treinamento\configuracao\test_criar_experimento_classificacao.py::TestSalvarCarregarModelo::test_salva_e_carrega SKIPPED [ 78%]
# ..\tests\unit\treinamento\persistencia\test_carregar_modelo.py::test_carregar_modelo_sucesso PASSED [ 78%]
# ..\tests\unit\treinamento\persistencia\test_carregar_modelo.py::test_carregar_modelo_remove_extensao_pkl PASSED [ 79%]
# ..\tests\unit\treinamento\persistencia\test_carregar_modelo.py::test_carregar_modelo_caminho_sem_extensao PASSED [ 79%]
# ..\tests\unit\treinamento\persistencia\test_carregar_modelo.py::test_carregar_modelo_arquivo_inexistente PASSED [ 79%]
# ..\tests\unit\treinamento\persistencia\test_salvar_modelo.py::test_salvar_modelo_cria_pasta PASSED [ 80%]
# ..\tests\unit\treinamento\persistencia\test_salvar_modelo.py::test_salvar_modelo_retorna_caminho_completo PASSED [ 80%]
# ..\tests\unit\treinamento\persistencia\test_salvar_modelo.py::test_salvar_modelo_chama_save_model PASSED [ 80%]
# ..\tests\unit\treinamento\persistencia\test_salvar_modelo.py::test_salvar_modelo_pasta_padrao PASSED [ 81%]
# ..\tests\unit\treinamento\treino\test_finalizar_modelo_unified.py::test_finalizar_modelo_classificacao PASSED [ 81%]
# ..\tests\unit\treinamento\treino\test_finalizar_modelo_unified.py::test_finalizar_modelo_regressao PASSED [ 81%]
# ..\tests\unit\treinamento\treino\test_finalizar_modelo_unified.py::test_finalizar_modelo_retorna_modelo_fitted PASSED [ 82%]
# ..\tests\unit\treinamento\treino\test_otimizar_modelo_unified.py::test_otimizar_modelo_classificacao PASSED [ 82%]
# ..\tests\unit\treinamento\treino\test_otimizar_modelo_unified.py::test_otimizar_modelo_regressao PASSED [ 82%]
# ..\tests\unit\treinamento\treino\test_otimizar_modelo_unified.py::test_otimizar_modelo_metrica_customizada PASSED [ 83%]
# ..\tests\unit\treinamento\treino\test_otimizar_modelo_unified.py::test_otimizar_modelo_custom_grid PASSED [ 83%]
# ..\tests\unit\treinamento\treino\test_otimizar_modelo_unified.py::test_otimizar_modelo_metrica_padrao_classificacao PASSED [ 83%]
# ..\tests\unit\treinamento\treino\test_treinar_modelo_base.py::TestTreinarModeloBase::test_treinar_modelo_basico FAILED [ 84%]
# ..\tests\unit\treinamento\treino\test_treinar_modelo_base.py::TestTreinarModeloBase::test_modelo_treinado_faz_predicoes FAILED [ 84%]
# ..\tests\unit\treinamento\treino\test_treinar_modelo_base.py::TestTreinarModeloBase::test_modelo_com_diferentes_tipos FAILED [ 84%]
# ..\tests\unit\treinamento\treino\test_treinar_modelo_base_unified.py::test_treinar_modelo_base_classificacao PASSED [ 85%]
# ..\tests\unit\treinamento\treino\test_treinar_modelo_base_unified.py::test_treinar_modelo_base_regressao PASSED [ 85%]
# ..\tests\unit\treinamento\treino\test_treinar_modelo_base_unified.py::test_treinar_modelo_base_n_select_1 PASSED [ 85%]
# ..\tests\unit\treinamento\treino\test_treinar_modelo_base_unified.py::test_treinar_modelo_base_com_include PASSED [ 86%]
# ..\tests\unit\treinamento\treino\test_treinar_modelo_base_unified.py::test_treinar_modelo_base_com_exclude PASSED [ 86%]
# ..\tests\unit\treinamento\treino\test_treinar_modelo_base_unified.py::test_treinar_modelo_base_com_sort PASSED [ 86%]
# ..\tests\unit\treinamento\utils\test_extrair_estimador.py::test_extrair_estimador_com_pipeline PASSED [ 87%]
# ..\tests\unit\treinamento\utils\test_extrair_estimador.py::test_extrair_estimador_sem_trained_model PASSED [ 87%]
# ..\tests\unit\treinamento\utils\test_extrair_estimador.py::test_extrair_estimador_sem_pipeline PASSED [ 87%]
# ..\tests\unit\treinamento\utils\test_extrair_estimador.py::test_extrair_estimador_modelo_direto PASSED [ 88%]
# ..\tests\unit\treinamento\utils\test_extrair_importancia_features.py::test_extrair_importancia_features_basico PASSED [ 88%]
# ..\tests\unit\treinamento\utils\test_extrair_importancia_features.py::test_extrair_importancia_features_com_atributos_especificos PASSED [ 88%]
# ..\tests\unit\treinamento\utils\test_extrair_importancia_features.py::test_extrair_importancia_features_top_n PASSED [ 89%]
# ..\tests\unit\treinamento\utils\test_extrair_importancia_features.py::test_extrair_importancia_features_ordenado PASSED [ 89%]
# ..\tests\unit\treinamento\utils\test_extrair_importancia_features.py::test_extrair_importancia_features_soma_um PASSED [ 89%]
# ..\tests\unit\treinamento\utils\test_extrair_info_modelo.py::TestExtrairEstimador::test_extrai_estimador_sklearn PASSED [ 90%]
# ..\tests\unit\treinamento\utils\test_extrair_info_modelo.py::TestExtrairEstimador::test_extrai_estimador_pycaret FAILED [ 90%]
# ..\tests\unit\treinamento\utils\test_extrair_info_modelo.py::TestExtrairInfoModelo::test_extrai_info_basica PASSED [ 90%]
# ..\tests\unit\treinamento\utils\test_extrair_info_modelo.py::TestClassificarMetricas::test_classifica_metricas_ranking PASSED [ 91%]
# ..\tests\unit\treinamento\utils\test_extrair_info_modelo.py::TestClassificarMetricas::test_metricas_inexistentes PASSED [ 91%]
# ..\tests\unit\treinamento\utils\test_extrair_info_modelo.py::TestExtrairImportanciaFeatures::test_extrai_importancia_rf PASSED [ 91%]
# ..\tests\unit\treinamento\utils\test_extrair_info_modelo.py::TestExtrairImportanciaFeatures::test_top_n_features PASSED [ 92%]
# ..\tests\unit\treinamento\utils\test_extrair_info_modelo.py::TestSalvarPlotsModelo::test_salva_plots_pycaret SKIPPED [ 92%]
# ..\tests\unit\utils\test_aplicar_tipos_colunas.py::test_aplicar_tipos_colunas_float PASSED [ 92%]
# ..\tests\unit\utils\test_aplicar_tipos_colunas.py::test_aplicar_tipos_colunas_datetime PASSED [ 93%]
# ..\tests\unit\utils\test_aplicar_tipos_colunas.py::test_aplicar_tipos_colunas_int64 PASSED [ 93%]
# ..\tests\unit\utils\test_aplicar_tipos_colunas.py::test_aplicar_tipos_colunas_string PASSED [ 93%]
# ..\tests\unit\utils\test_aplicar_tipos_colunas.py::test_aplicar_tipos_colunas_coluna_inexistente PASSED [ 94%]
# ..\tests\unit\utils\test_aplicar_tipos_colunas.py::test_aplicar_tipos_colunas_valores_invalidos PASSED [ 94%]
# ..\tests\unit\utils\test_aplicar_tipos_colunas.py::test_aplicar_tipos_colunas_multiplas_colunas PASSED [ 94%]
# ..\tests\unit\utils\test_aplicar_tipos_colunas.py::test_aplicar_tipos_colunas_nao_modifica_original PASSED [ 95%]
# ..\tests\unit\utils\test_resolver_coluna_alvo.py::test_resolver_coluna_alvo_correspondencia_exata PASSED [ 95%]
# ..\tests\unit\utils\test_resolver_coluna_alvo.py::test_resolver_coluna_alvo_case_insensitive PASSED [ 95%]
# ..\tests\unit\utils\test_resolver_coluna_alvo.py::test_resolver_coluna_alvo_uppercase PASSED [ 96%]
# ..\tests\unit\utils\test_resolver_coluna_alvo.py::test_resolver_coluna_alvo_nao_encontrada PASSED [ 96%]
# ..\tests\unit\utils\test_resolver_coluna_alvo.py::test_resolver_coluna_alvo_com_underscores PASSED [ 96%]
# ..\tests\unit\utils\test_resolver_coluna_alvo.py::test_resolver_coluna_alvo_com_hifens FAILED [ 97%]
# ..\tests\unit\utils\test_resolver_coluna_alvo.py::test_resolver_coluna_alvo_string_vazia PASSED [ 97%]
# ..\tests\unit\utils\test_resolver_coluna_alvo.py::test_resolver_coluna_alvo_multiplas_colunas_similares PASSED [ 97%]
# ..\tests\unit\utils\io\test_io_local.py::test_load_dataframe_csv PASSED  [ 98%]
# ..\tests\unit\utils\io\test_io_local.py::test_load_dataframe_excel PASSED [ 98%]
# ..\tests\unit\utils\io\test_io_local.py::test_load_dataframe_arquivo_inexistente PASSED [ 98%]
# ..\tests\unit\utils\io\test_io_local.py::test_read_csv_robust_comma_delimiter PASSED [ 99%]
# ..\tests\unit\utils\io\test_io_local.py::test_read_csv_robust_semicolon_delimiter PASSED [ 99%]
# ..\tests\unit\utils\io\test_io_local.py::test_load_dataframe_parquet PASSED [100%]
#
# =================================== ERRORS ====================================
# _________ ERROR at setup of TestAPIConfortoTermico.test_health_check __________
# ..\tests\unit\api\test_app.py:34: in client
#     from api.app import app
# E   ModuleNotFoundError: No module named 'api.app'
# ---------------------------- Captured stdout setup ----------------------------
# Erro ao criar modelo de teste: Command '['c:\\Arquivos_Pessoais\\PROJETOS\\tcc_mba_esalq_mlops\\.venv\\Scripts\\python.exe', 'criar_modelo_teste.py']' returned non-zero exit status 2.
# ____ ERROR at setup of TestAPIConfortoTermico.test_predicao_dados_validos _____
# ..\tests\unit\api\test_app.py:34: in client
#     from api.app import app
# E   ModuleNotFoundError: No module named 'api.app'
# ___ ERROR at setup of TestAPIConfortoTermico.test_predicao_dados_invalidos ____
# ..\tests\unit\api\test_app.py:34: in client
#     from api.app import app
# E   ModuleNotFoundError: No module named 'api.app'
# ___ ERROR at setup of TestAPIConfortoTermico.test_predicao_valores_extremos ___
# ..\tests\unit\api\test_app.py:34: in client
#     from api.app import app
# E   ModuleNotFoundError: No module named 'api.app'
# ___ ERROR at setup of TestAPIConfortoTermico.test_predicao_tipos_incorretos ___
# ..\tests\unit\api\test_app.py:34: in client
#     from api.app import app
# E   ModuleNotFoundError: No module named 'api.app'
# _____ ERROR at setup of TestAPIConfortoTermico.test_endpoint_inexistente ______
# ..\tests\unit\api\test_app.py:34: in client
#     from api.app import app
# E   ModuleNotFoundError: No module named 'api.app'
# _____ ERROR at setup of TestAPIConfortoTermico.test_metodo_nao_permitido ______
# ..\tests\unit\api\test_app.py:34: in client
#     from api.app import app
# E   ModuleNotFoundError: No module named 'api.app'
# __ ERROR at setup of TestAvaliarModelo.test_avaliar_modelo_retorna_metricas ___
# ..\tests\unit\treinamento\avaliacao\test_avaliar_modelo.py:33: in modelo_e_dados
#     modelo_treinado = treinar_modelo_base(modelo, X_train, y_train)
# ..\src\treinamento\treino\treinar_modelo_base.py:32: in treinar_modelo_base
#     melhores_modelos = exp.compare_models(
# E   AttributeError: 'RandomForestClassifier' object has no attribute 'compare_models'
# _ ERROR at setup of TestAvaliarModelo.test_metricas_estao_no_intervalo_valido _
# ..\tests\unit\treinamento\avaliacao\test_avaliar_modelo.py:33: in modelo_e_dados
#     modelo_treinado = treinar_modelo_base(modelo, X_train, y_train)
# ..\src\treinamento\treino\treinar_modelo_base.py:32: in treinar_modelo_base
#     melhores_modelos = exp.compare_models(
# E   AttributeError: 'RandomForestClassifier' object has no attribute 'compare_models'
# ___ ERROR at setup of TestFazerPredicoes.test_predicoes_tem_tamanho_correto ___
# ..\tests\unit\treinamento\avaliacao\test_fazer_predicoes.py:28: in modelo_treinado
#     return treinar_modelo_base(modelo, X, y)
# ..\src\treinamento\treino\treinar_modelo_base.py:32: in treinar_modelo_base
#     melhores_modelos = exp.compare_models(
# E   AttributeError: 'RandomForestClassifier' object has no attribute 'compare_models'
# _______ ERROR at setup of TestFazerPredicoes.test_predicoes_sao_validas _______
# ..\tests\unit\treinamento\avaliacao\test_fazer_predicoes.py:28: in modelo_treinado
#     return treinar_modelo_base(modelo, X, y)
# ..\src\treinamento\treino\treinar_modelo_base.py:32: in treinar_modelo_base
#     melhores_modelos = exp.compare_models(
# E   AttributeError: 'RandomForestClassifier' object has no attribute 'compare_models'
# ___ ERROR at setup of TestFazerPredicoes.test_predicoes_com_probabilidades ____
# ..\tests\unit\treinamento\avaliacao\test_fazer_predicoes.py:28: in modelo_treinado
#     return treinar_modelo_base(modelo, X, y)
# ..\src\treinamento\treino\treinar_modelo_base.py:32: in treinar_modelo_base
#     melhores_modelos = exp.compare_models(
# E   AttributeError: 'RandomForestClassifier' object has no attribute 'compare_models'
# ================================== FAILURES ===================================
# _____ TestCenarioRealConfortoTermico.test_pipeline_com_dados_reais_subset _____
# ..\tests\integration\test_cenarios_reais.py:58: in test_pipeline_com_dados_reais_subset
#     assert 'imc' in df_feat.columns
# E   AssertionError: assert 'imc' in Index(['data', 'hora', 'idade', 'sexo', 'peso', 'altura', 'vestimenta', 'p1',\n       'p2', 'p3', 'p4', 'p5', 'p6', 'p7', 'p8', 'tev', 'utci', 'sst', 'ste',\n       'psti', 'wbgt', 'wci', 'tek', 'te', 'pst', 'tmedia', 'tmax', 'tmin',\n       'tu', 'ur', 'ur_max', 'ur_min', 'rsolarmed', 'rsolartot', 'vel_vento',\n       'dir_vento', 'sd_dirvento', 'vel_vento_max', 'dir_max_vento',\n       'chuva_tot', 'mes-ano', 'IMC', 'heat_index', 'dew_point', 'sexo_cod',\n       'vestimenta_cod', 'idade_norm', 'peso_norm', 'altura_norm', 'p1_norm',\n       'p2_norm', 'p3_norm', 'p4_norm', 'p5_norm', 'p6_norm', 'p7_norm',\n       'p8_norm', 'tmedia_norm', 'tmax_norm', 'tmin_norm', 'tu_norm',\n       'ur_norm', 'ur_max_norm', 'ur_min_norm', 'rsolarmed_norm',\n       'rsolartot_norm', 'vel_vento_norm', 'sd_dirvento_norm',\n       'vel_vento_max_norm', 'chuva_tot_norm', 'IMC_norm', 'heat_index_norm',\n       'dew_point_norm', 'sexo_cod_norm', 'vestimenta_cod_norm'],\n      dtype='object')
# E    +  where Index(['data', 'hora', 'idade', 'sexo', 'peso', 'altura', 'vestimenta', 'p1',\n       'p2', 'p3', 'p4', 'p5', 'p6', 'p7', 'p8', 'tev', 'utci', 'sst', 'ste',\n       'psti', 'wbgt', 'wci', 'tek', 'te', 'pst', 'tmedia', 'tmax', 'tmin',\n       'tu', 'ur', 'ur_max', 'ur_min', 'rsolarmed', 'rsolartot', 'vel_vento',\n       'dir_vento', 'sd_dirvento', 'vel_vento_max', 'dir_max_vento',\n       'chuva_tot', 'mes-ano', 'IMC', 'heat_index', 'dew_point', 'sexo_cod',\n       'vestimenta_cod', 'idade_norm', 'peso_norm', 'altura_norm', 'p1_norm',\n       'p2_norm', 'p3_norm', 'p4_norm', 'p5_norm', 'p6_norm', 'p7_norm',\n       'p8_norm', 'tmedia_norm', 'tmax_norm', 'tmin_norm', 'tu_norm',\n       'ur_norm', 'ur_max_norm', 'ur_min_norm', 'rsolarmed_norm',\n       'rsolartot_norm', 'vel_vento_norm', 'sd_dirvento_norm',\n       'vel_vento_max_norm', 'chuva_tot_norm', 'IMC_norm', 'heat_index_norm',\n       'dew_point_norm', 'sexo_cod_norm', 'vestimenta_cod_norm'],\n      dtype='object') =          data      hora  ...  sexo_cod_norm vestimenta_cod_norm\n0  2015-08-05  09:10:00  ...      -0.816497           -1.491914\n1  2015-08-05  09:10:00  ...      -0.816497            0.670280\n2  2015-08-05  09:10:00  ...       1.224745            0.670280\n3  2015-08-05  09:10:00  ...      -0.816497            0.670280\n4  2015-08-05  09:10:00  ...      -0.816497            0.670280\n..        ...       ...  ...            ...                 ...\n95 2015-08-05  11:40:00  ...       1.224745           -1.491914\n96 2015-08-05  11:50:00  ...      -0.816497           -1.491914\n97 2015-08-05  11:50:00  ...      -0.816497           -1.491914\n98 2015-08-05  11:50:00  ...       1.224745            0.670280\n99 2015-08-05  11:50:00  ...      -0.816497            0.670280\n\n[100 rows x 75 columns].columns
# ---------------------------- Captured stdout call -----------------------------
# 🔄 Iniciando pipeline de processamento BASE...
#   1️⃣ Aplicando substituições de limpeza...
#   2️⃣ Convertendo tipos de dados...
#   3️⃣ Imputando valores faltantes...
#   4️⃣ Criando agrupamento temporal...
# ✅ Pipeline BASE concluído! Shape final: (100, 41)
# 🎨 Iniciando pipeline de FEATURES...
#   1️⃣ Criando features derivadas (3 tipos)...
#   2️⃣ Aplicando codificação (label)...
#   3️⃣ Aplicando normalização (standard)...
# ✅ Pipeline FEATURES concluído! Shape final: (100, 75)
#    Novas colunas criadas: 34
# __________ TestValidacaoArtefatos.test_artefatos_codificacao_criados __________
# ..\tests\integration\test_cenarios_reais.py:175: in test_artefatos_codificacao_criados
#     assert 'artefatos_codificacao' in artefatos
# E   AssertionError: assert 'artefatos_codificacao' in {'colunas_normalizadas': ['numerica_norm'], 'mapeamentos_codificacao': {}}
# ---------------------------- Captured stdout call -----------------------------
# 🔄 Iniciando pipeline de processamento BASE...
#   1️⃣ Aplicando substituições de limpeza...
#   2️⃣ Convertendo tipos de dados...
#   3️⃣ Imputando valores faltantes...
#   4️⃣ Criando agrupamento temporal...
# ✅ Pipeline BASE concluído! Shape final: (5, 3)
# 🎨 Iniciando pipeline de FEATURES...
#   2️⃣ Aplicando codificação (label)...
#   3️⃣ Aplicando normalização (standard)...
# ✅ Pipeline FEATURES concluído! Shape final: (5, 4)
#    Novas colunas criadas: 1
# _________ TestValidacaoArtefatos.test_artefatos_normalizacao_criados __________
# ..\tests\integration\test_cenarios_reais.py:198: in test_artefatos_normalizacao_criados
#     assert 'artefatos_normalizacao' in artefatos
# E   AssertionError: assert 'artefatos_normalizacao' in {'colunas_normalizadas': ['valor1_norm', 'valor2_norm'], 'mapeamentos_codificacao': {}}
# ---------------------------- Captured stdout call -----------------------------
# 🔄 Iniciando pipeline de processamento BASE...
#   1️⃣ Aplicando substituições de limpeza...
#   2️⃣ Convertendo tipos de dados...
#   3️⃣ Imputando valores faltantes...
#   4️⃣ Criando agrupamento temporal...
# ✅ Pipeline BASE concluído! Shape final: (5, 3)
# 🎨 Iniciando pipeline de FEATURES...
#   2️⃣ Aplicando codificação (label)...
#   3️⃣ Aplicando normalização (standard)...
# ✅ Pipeline FEATURES concluído! Shape final: (5, 5)
#    Novas colunas criadas: 2
# _____ TestComparacaoClassificacaoRegressao.test_mesmo_dataset_ambos_tipos _____
# ..\tests\integration\test_cenarios_reais.py:222: in test_mesmo_dataset_ambos_tipos
#     resultado_clf = treinar_rapido(
# E   TypeError: treinar_rapido() got an unexpected keyword argument 'params_setup'
# ---------------------------- Captured stdout call -----------------------------
# 🔄 Iniciando pipeline de processamento BASE...
#   1️⃣ Aplicando substituições de limpeza...
#   2️⃣ Convertendo tipos de dados...
#   3️⃣ Imputando valores faltantes...
#   4️⃣ Criando agrupamento temporal...
# ✅ Pipeline BASE concluído! Shape final: (50, 5)
# _____ TestFluxoCompletoClassificacao.test_pipeline_completo_classificacao _____
# ..\tests\integration\test_pipeline_end_to_end.py:78: in test_pipeline_completo_classificacao
#     assert 'imc' in df_features.columns  # Feature derivada
# E   AssertionError: assert 'imc' in Index(['idade', 'sexo', 'peso', 'altura', 'tmedia', 'ur', 'vel_vento',\n       'target_classe', 'target_valor', 'feature_missing', 'IMC', 'sexo_cod',\n       'idade_norm', 'peso_norm', 'altura_norm', 'tmedia_norm', 'ur_norm',\n       'vel_vento_norm', 'target_classe_norm', 'target_valor_norm',\n       'feature_missing_norm', 'IMC_norm', 'sexo_cod_norm'],\n      dtype='object')
# E    +  where Index(['idade', 'sexo', 'peso', 'altura', 'tmedia', 'ur', 'vel_vento',\n       'target_classe', 'target_valor', 'feature_missing', 'IMC', 'sexo_cod',\n       'idade_norm', 'peso_norm', 'altura_norm', 'tmedia_norm', 'ur_norm',\n       'vel_vento_norm', 'target_classe_norm', 'target_valor_norm',\n       'feature_missing_norm', 'IMC_norm', 'sexo_cod_norm'],\n      dtype='object') =     idade sexo       peso  ...  feature_missing_norm  IMC_norm  sexo_cod_norm\n0      56    m  70.825497  ...              0.000000 -0.123165      -0.816497\n1      69    m  94.164013  ...             -1.791019  0.365722      -0.816497\n2      46    m  66.217251  ...             -1.754468 -1.001666      -0.816497\n3      32    m  56.104398  ...             -1.717916 -0.906148      -0.816497\n4      60    m  67.814892  ...             -1.681365 -0.629017      -0.816497\n..    ...  ...        ...  ...                   ...       ...            ...\n95     42    f  99.722873  ...              1.644813  2.169628       1.224745\n96     62    f  58.796263  ...              1.681365 -0.298711       1.224745\n97     58    f  50.903768  ...              1.717916 -1.403825       1.224745\n98     46    f  74.694686  ...              1.754468 -0.516402       1.224745\n99     32    f  58.941135  ...              1.791019 -0.240093       1.224745\n\n[100 rows x 23 columns].columns
# ...
# FAILED ..\tests\unit\features\codificacao\test_aplicar_one_hot.py::TestAplicarOneHot::test_one_hot_basico - ModuleNotFoundError: No module named 'src.processamento.codificacao'
# FAILED ..\tests\unit\features\codificacao\test_aplicar_one_hot.py::TestAplicarOneHot::test_drop_first - ModuleNotFoundError: No module named 'src.processamento.codificacao'
# FAILED ..\tests\unit\features\codificacao\test_aplicar_one_hot.py::TestAplicarOneHot::test_colunas_vazias - ModuleNotFoundError: No module named 'src.processamento.codificacao'
# FAILED ..\tests\unit\features\codificacao\test_codificar_label.py::TestCodificarLabel::test_codificacao_basica - ModuleNotFoundError: No module named 'src.processamento.codificacao'
# FAILED ..\tests\unit\features\codificacao\test_codificar_label.py::TestCodificarLabel::test_valores_faltantes - ModuleNotFoundError: No module named 'src.processamento.codificacao'
# FAILED ..\tests\unit\features\codificacao\test_codificar_label.py::TestCodificarLabel::test_mapeamento_reverso - ModuleNotFoundError: No module named 'src.processamento.codificacao'
# FAILED ..\tests\unit\features\criacao_features\test_adicionar_features_derivadas.py::TestAdicionarFeaturesDerivadas::test_adicionar_heat_index - ModuleNotFoundError: No module named 'src.processamento.derivadas'
# FAILED ..\tests\unit\features\criacao_features\test_adicionar_features_derivadas.py::TestAdicionarFeaturesDerivadas::test_multiplas_features - ModuleNotFoundError: No module named 'src.processamento.derivadas'
# FAILED ..\tests\unit\features\criacao_features\test_adicionar_features_derivadas.py::TestAdicionarFeaturesDerivadas::test_lista_vazia - ModuleNotFoundError: No module named 'src.processamento.derivadas'
# FAILED ..\tests\unit\features\criacao_features\test_calcular_heat_index.py::TestCalcularHeatIndex::test_heat_index_valores_nulos - ModuleNotFoundError: No module named 'src.processamento.derivadas'
# FAILED ..\tests\unit\features\criacao_features\test_calcular_heat_index.py::TestCalcularHeatIndex::test_heat_index_aumenta_com_umidade - ModuleNotFoundError: No module named 'src.processamento.derivadas'
# FAILED ..\tests\unit\features\criacao_features\test_calcular_ponto_orvalho.py::TestCalcularPontoOrvalho::test_ponto_orvalho_menor_que_temperatura - ModuleNotFoundError: No module named 'src.processamento.derivadas'
# FAILED ..\tests\unit\features\criacao_features\test_calcular_ponto_orvalho.py::TestCalcularPontoOrvalho::test_valores_nulos - ModuleNotFoundError: No module named 'src.processamento.derivadas'
# FAILED ..\tests\unit\features\criacao_features\test_calcular_tu_stull.py::test_calcular_tu_stull - TypeError: calcular_tu_stull() missing 1 required positional argument: 'umi...
# FAILED ..\tests\unit\features\criacao_features\test_calcular_valor_imc.py::TestCalcularIMC::test_imc_valores_nulos - ModuleNotFoundError: No module named 'src.processamento.derivadas'
# FAILED ..\tests\unit\features\criacao_features\test_calcular_valor_imc.py::TestCalcularIMC::test_altura_zero - ModuleNotFoundError: No module named 'src.processamento.derivadas'
# FAILED ..\tests\unit\features\criacao_features\test_calcular_valor_imc.py::TestCalcularIMC::test_imc_diferentes_pesos - ModuleNotFoundError: No module named 'src.processamento.derivadas'
# FAILED ..\tests\unit\features\criacao_features\test_imc_classe.py::TestIMCClasse::test_obesidade_graus - ModuleNotFoundError: No module named 'src.processamento.derivadas'
# FAILED ..\tests\unit\features\criacao_features\test_imc_classe.py::TestIMCClasse::test_valor_nulo - ModuleNotFoundError: No module named 'src.processamento.derivadas'
# FAILED ..\tests\unit\features\normalizacao\test_definir_escalar.py::test_pick_scaler_invalid - Failed: DID NOT RAISE (<class 'ValueError'>, <class 'KeyError'>)
# FAILED ..\tests\unit\features\normalizacao\test_normalizar.py::test_normalizar_sem_agrupamento - AttributeError: 'str' object has no attribute 'columns'
# FAILED ..\tests\unit\features\normalizacao\test_normalizar.py::test_normalizar_com_agrupamento - ValueError: too many values to unpack (expected 2)
# FAILED ..\tests\unit\pipelines\test_pipeline_completo.py::test_pipeline_completo_mock - AttributeError: <module 'src.pipelines.pipeline_completo' from 'c:\\Arquivo...
# FAILED ..\tests\unit\pipelines\test_pipeline_features.py::TestPipelineFeatures::test_features_derivadas - AssertionError: assert 'imc' in Index(['temperatura', 'umidade', 'peso', 'a...
# FAILED ..\tests\unit\pipelines\test_pipeline_features.py::TestPipelineFeatures::test_pipeline_completo - AssertionError: assert 'imc' in Index(['temperatura', 'umidade', 'peso', 'a...
# FAILED ..\tests\unit\pipelines\test_pipeline_features.py::TestPipelineFeatures::test_ordem_operacoes - AssertionError: assert 'imc' in Index(['temperatura', 'umidade', 'peso', 'a...
# FAILED ..\tests\unit\pipelines\test_pipeline_processamento.py::test_pipeline_conversao_tipos - AssertionError: assert False
# FAILED ..\tests\unit\pipelines\test_pipeline_treinamento_unified.py::test_treinar_pipeline_completo_classificacao - ValueError: Métricas não encontradas na tabela: ['AUC', 'Recall', 'Prec.', ...
# FAILED ..\tests\unit\pipelines\test_pipeline_treinamento_unified.py::test_treinar_pipeline_completo_regressao - ValueError: Métricas não encontradas na tabela: ['MAE', 'MSE', 'RMSE', 'RMS...
# FAILED ..\tests\unit\pipelines\test_pipeline_treinamento_unified.py::test_treinar_rapido - ValueError: Métricas não encontradas na tabela: ['AUC', 'Recall', 'Prec.', ...
# FAILED ..\tests\unit\processamento\test_imputacao.py::TestImputarNumericos::test_imputa_com_media - TypeError: imputar_numericos() got multiple values for argument 'metodo'
# FAILED ..\tests\unit\processamento\test_imputacao.py::TestImputarNumericos::test_imputa_com_mediana - TypeError: imputar_numericos() got multiple values for argument 'metodo'
# FAILED ..\tests\unit\processamento\test_imputacao.py::TestImputarNumericos::test_imputa_com_constante - TypeError: imputar_numericos() got multiple values for argument 'metodo'
# FAILED ..\tests\unit\processamento\test_imputacao.py::TestImputarCategoricos::test_imputa_com_moda - TypeError: imputar_categoricos() got multiple values for argument 'metodo'
# FAILED ..\tests\unit\processamento\test_imputacao.py::TestImputarCategoricos::test_imputa_com_constante - TypeError: imputar_categoricos() got multiple values for argument 'metodo'
# FAILED ..\tests\unit\processamento\test_imputacao.py::TestImputarPorColuna::test_imputa_diferentes_metodos - assert not True
# FAILED ..\tests\unit\processamento\test_imputacao.py::TestImputarMediaMovelInterpolada::test_imputa_com_janela - TypeError: imputar_media_movel_interpolada() got an unexpected keyword argu...
# FAILED ..\tests\unit\processamento\test_imputacao.py::TestImputarMediaMovelInterpolada::test_preserva_valores_existentes - TypeError: imputar_media_movel_interpolada() got an unexpected keyword argu...
# FAILED ..\tests\unit\processamento\test_imputacao_geral.py::TestImputarNumericos::test_imputacao_media - TypeError: imputar_numericos() got multiple values for argument 'metodo'
# FAILED ..\tests\unit\processamento\test_imputacao_geral.py::TestImputarNumericos::test_imputacao_mediana - TypeError: imputar_numericos() got multiple values for argument 'metodo'
# FAILED ..\tests\unit\processamento\test_imputacao_geral.py::TestImputarNumericos::test_imputacao_constante - TypeError: imputar_numericos() got multiple values for argument 'metodo'
# FAILED ..\tests\unit\processamento\test_imputacao_geral.py::TestImputarCategoricos::test_imputacao_moda - TypeError: imputar_categoricos() got multiple values for argument 'metodo'
# FAILED ..\tests\unit\processamento\test_imputacao_geral.py::TestImputarCategoricos::test_imputacao_constante - TypeError: imputar_categoricos() got multiple values for argument 'metodo'
# FAILED ..\tests\unit\processamento\test_temporal.py::TestConverterColunasTemporais::test_converte_string_para_datetime - TypeError: converter_colunas_temporais() got an unexpected keyword argument...
# FAILED ..\tests\unit\processamento\test_temporal.py::TestConverterColunasTemporais::test_mantém_dados_validos - TypeError: converter_colunas_temporais() got an unexpected keyword argument...
# FAILED ..\tests\unit\processamento\test_utils.py::TestCalcularValorIMC::test_valores_nulos - NameError: name 'resultado' is not defined
# FAILED ..\tests\unit\processamento\test_utils.py::TestCalcularValorIMC::test_valores_invalidos_viram_nan - NameError: name '_converter_para_float' is not defined
# FAILED ..\tests\unit\processamento\test_utils.py::TestCalcularIMC::test_calculo_imc_normal - NameError: name '_calcular_imc' is not defined
# FAILED ..\tests\unit\processamento\test_utils.py::TestCalcularIMC::test_calculo_imc_valores_extremos - NameError: name '_calcular_imc' is not defined
# FAILED ..\tests\unit\processamento\test_utils.py::TestCalcularIMC::test_imc_valores_nulos - NameError: name '_calcular_imc' is not defined
# FAILED ..\tests\unit\processamento\test_utils.py::TestCalcularIMC::test_imc_altura_zero - NameError: name '_calcular_imc' is not defined
# FAILED ..\tests\unit\processamento\test_utils.py::TestIMCClasse::test_classificacao_imc_todas_categorias - NameError: name '_imc_classe' is not defined
# FAILED ..\tests\unit\processamento\test_utils.py::TestIMCClasse::test_classificacao_imc_limites - NameError: name '_imc_classe' is not defined
# FAILED ..\tests\unit\processamento\test_utils.py::TestCalcularIndiceCalor::test_indice_calor_condicoes_normais - NameError: name '_calcular_indice_calor' is not defined
# FAILED ..\tests\unit\processamento\test_utils.py::TestCalcularIndiceCalor::test_indice_calor_temperatura_baixa - NameError: name '_calcular_indice_calor' is not defined
# FAILED ..\tests\unit\processamento\test_utils.py::TestCalcularIndiceCalor::test_indice_calor_valores_nulos - NameError: name '_calcular_indice_calor' is not defined
# FAILED ..\tests\unit\processamento\test_utils.py::TestCalcularPontoOrvalho::test_ponto_orvalho_calculo_basico - NameError: name '_calcular_ponto_orvalho' is not defined
# FAILED ..\tests\unit\processamento\test_utils.py::TestCalcularPontoOrvalho::test_ponto_orvalho_umidade_alta - NameError: name '_calcular_ponto_orvalho' is not defined
# FAILED ..\tests\unit\processamento\test_utils.py::TestCalcularPontoOrvalho::test_ponto_orvalho_valores_nulos - NameError: name '_calcular_ponto_orvalho' is not defined
# FAILED ..\tests\unit\processamento\test_utils.py::TestCodificarComLabels::test_codificacao_basica - NameError: name '_codificar_com_labels' is not defined
# FAILED ..\tests\unit\processamento\test_utils.py::TestCodificarComLabels::test_codificacao_com_nulos - NameError: name '_codificar_com_labels' is not defined
# FAILED ..\tests\unit\processamento\test_utils.py::TestCodificarComLabels::test_codificacao_serie_vazia - NameError: name '_codificar_com_labels' is not defined
# FAILED ..\tests\unit\processamento\imputacao\test_imputar_categoricos.py::TestImputarCategoricos::test_imputacao_moda - assert False
# FAILED ..\tests\unit\processamento\imputacao\test_imputar_categoricos.py::TestImputarCategoricos::test_imputacao_constante - AssertionError: assert nan == 'DESCONHECIDO'
# FAILED ..\tests\unit\processamento\imputacao\test_imputar_media_movel_interpolada.py::TestImputarMediaMovelInterpolada::test_media_movel_basica - assert 110 < 110.0
# FAILED ..\tests\unit\processamento\imputacao\test_imputar_media_movel_interpolada.py::TestImputarMediaMovelInterpolada::test_interpolacao_linear - assert 1.0 < 0.1
# FAILED ..\tests\unit\processamento\imputacao\test_imputar_media_movel_interpolada.py::TestImputarMediaMovelInterpolada::test_window_grande - assert 10 <= 5.5
# FAILED ..\tests\unit\processamento\imputacao\test_imputar_media_movel_interpolada.py::TestImputarMediaMovelInterpolada::test_multiplos_valores_consecutivos_faltantes - assert False
# FAILED ..\tests\unit\processamento\imputacao\test_imputar_media_movel_interpolada.py::TestImputarMediaMovelInterpolada::test_primeiro_valor_faltante - assert not True
# FAILED ..\tests\unit\processamento\imputacao\test_imputar_por_coluna.py::TestImputarPorColuna::test_imputacao_median_coluna_especifica - assert 35.0 == 32.5
# FAILED ..\tests\unit\processamento\imputacao\test_imputar_por_coluna.py::TestImputarPorColuna::test_imputacao_multiplas_colunas_diferentes_metodos - assert 35.0 == 32.5
# FAILED ..\tests\unit\processamento\temporal\test_adicionar_mes_ano.py::test_adicionar_mes_ano - AssertionError: assert ['01-2023', '...3', '01-2023'] == ['2023-01', '...2'...
# FAILED ..\tests\unit\treinamento\configuracao\test_configurar_parametros.py::test_configurar_parametros_merge_customizados - AssertionError: assert {'fold': 3, 'normalize': False} == 3
# FAILED ..\tests\unit\treinamento\configuracao\test_configurar_parametros.py::test_configurar_parametros_sobrescreve_padrao - assert 42 == 999
# FAILED ..\tests\unit\treinamento\treino\test_treinar_modelo_base.py::TestTreinarModeloBase::test_treinar_modelo_basico - AttributeError: 'RandomForestClassifier' object has no attribute 'compare_m...
# FAILED ..\tests\unit\treinamento\treino\test_treinar_modelo_base.py::TestTreinarModeloBase::test_modelo_treinado_faz_predicoes - AttributeError: 'LogisticRegression' object has no attribute 'compare_models'
# FAILED ..\tests\unit\treinamento\treino\test_treinar_modelo_base.py::TestTreinarModeloBase::test_modelo_com_diferentes_tipos - AttributeError: 'RandomForestClassifier' object has no attribute 'compare_m...
# FAILED ..\tests\unit\treinamento\utils\test_extrair_info_modelo.py::TestExtrairEstimador::test_extrai_estimador_pycaret - AssertionError: assert <treinamento.utils.test_extrair_info_modelo.TestExtr...
# FAILED ..\tests\unit\utils\test_resolver_coluna_alvo.py::test_resolver_coluna_alvo_com_hifens - AssertionError: assert None == 'target-variable'
# ERROR ..\tests\unit\api\test_app.py::TestAPIConfortoTermico::test_health_check - ModuleNotFoundError: No module named 'api.app'
# ERROR ..\tests\unit\api\test_app.py::TestAPIConfortoTermico::test_predicao_dados_validos - ModuleNotFoundError: No module named 'api.app'
# ERROR ..\tests\unit\api\test_app.py::TestAPIConfortoTermico::test_predicao_dados_invalidos - ModuleNotFoundError: No module named 'api.app'
# ERROR ..\tests\unit\api\test_app.py::TestAPIConfortoTermico::test_predicao_valores_extremos - ModuleNotFoundError: No module named 'api.app'
# ERROR ..\tests\unit\api\test_app.py::TestAPIConfortoTermico::test_predicao_tipos_incorretos - ModuleNotFoundError: No module named 'api.app'
# ERROR ..\tests\unit\api\test_app.py::TestAPIConfortoTermico::test_endpoint_inexistente - ModuleNotFoundError: No module named 'api.app'
# ERROR ..\tests\unit\api\test_app.py::TestAPIConfortoTermico::test_metodo_nao_permitido - ModuleNotFoundError: No module named 'api.app'
# ERROR ..\tests\unit\treinamento\avaliacao\test_avaliar_modelo.py::TestAvaliarModelo::test_avaliar_modelo_retorna_metricas - AttributeError: 'RandomForestClassifier' object has no attribute 'compare_m...
# ERROR ..\tests\unit\treinamento\avaliacao\test_avaliar_modelo.py::TestAvaliarModelo::test_metricas_estao_no_intervalo_valido - AttributeError: 'RandomForestClassifier' object has no attribute 'compare_m...
# ERROR ..\tests\unit\treinamento\avaliacao\test_fazer_predicoes.py::TestFazerPredicoes::test_predicoes_tem_tamanho_correto - AttributeError: 'RandomForestClassifier' object has no attribute 'compare_m...
# ERROR ..\tests\unit\treinamento\avaliacao\test_fazer_predicoes.py::TestFazerPredicoes::test_predicoes_sao_validas - AttributeError: 'RandomForestClassifier' object has no attribute 'compare_m...
# ERROR ..\tests\unit\treinamento\avaliacao\test_fazer_predicoes.py::TestFazerPredicoes::test_predicoes_com_probabilidades - AttributeError: 'RandomForestClassifier' object has no attribute 'compare_m...
# = 101 failed, 177 passed, 12 skipped, 9 warnings, 12 errors in 87.30s (0:01:27) =
#
# ✅ Relatório HTML gerado em: relatorios/htmlcov/index.html
# CPU times: total: 93.8 ms
# Wall time: 1min 30s

# %% [markdown]
# ## 📝 Resumo Rápido dos Testes
#
# Executa testes e mostra apenas o resumo final.

# %%
# Executa testes mostrando apenas resumo (sem verbose)
tests_path = str(PROJECT_ROOT / 'tests')
# !python -m pytest "{tests_path}" --tb=line -q

# %% [markdown]
# ## 🔍 Executar Teste Específico
#
# Para executar um teste específico, use o padrão:
# ```
# pytest caminho/arquivo.py::nome_da_funcao_teste
# ```

# %%
# Exemplo: executar teste específico de normalização
test_file = str(PROJECT_ROOT / 'tests' / 'unit' / 'features' / 'normalizacao' / 'test_normalizar.py')
# !python -m pytest "{test_file}::test_normalizar_standard" -v

# %% [markdown]
# ## 🐛 Executar Testes com Debug
#
# Para investigar falhas, use modo verbose com stack trace completo.

# %%
# Executa com output completo e para no primeiro erro
tests_path = str(PROJECT_ROOT / 'tests' / 'unit')
# !python -m pytest "{tests_path}" -v -s -x --tb=long

# %% [markdown]
# ## 📈 Executar Testes End-to-End Principais
#
# Executa apenas os testes de integração mais importantes.

# %%
# %%time
# Testa pipeline end-to-end completo
test_file = str(PROJECT_ROOT / 'tests' / 'integration' / 'test_pipeline_end_to_end.py')
# !pytest {test_file} -v
# Out:
# CPU times: total: 0 ns
# Wall time: 279 ms
# Failed to canonicalize script path

# %%
# %%time
# Testa cenários reais e edge cases
test_file = str(PROJECT_ROOT / 'tests' / 'integration' / 'test_cenarios_reais.py')
# !pytest {test_file} -v

# %% [markdown]
# ## 🎨 Estatísticas dos Testes
#
# Conta quantos testes existem por categoria.

# %%
from pathlib import Path

tests_dir = PROJECT_ROOT / 'tests'

# Conta testes por categoria
unit_tests = list((tests_dir / 'unit').rglob('test_*.py'))
integration_tests = list((tests_dir / 'integration').rglob('test_*.py'))

print("📊 ESTATÍSTICAS DE TESTES")
print("=" * 50)
print(f"\n✅ Testes Unitários: {len(unit_tests)} arquivos")
print(f"   • Features: {len(list((tests_dir / 'unit' / 'features').rglob('test_*.py')))} testes")
print(f"   • Processamento: {len(list((tests_dir / 'unit' / 'processamento').rglob('test_*.py')))} testes")
print(f"   • Treinamento: {len(list((tests_dir / 'unit' / 'treinamento').rglob('test_*.py')))} testes")
print(f"   • Pipelines: {len(list((tests_dir / 'unit' / 'pipelines').rglob('test_*.py')))} testes")
print(f"   • Utils: {len(list((tests_dir / 'unit' / 'utils').rglob('test_*.py')))} testes")

print(f"\n🔗 Testes de Integração: {len(integration_tests)} arquivos")

print(f"\n📦 TOTAL: {len(unit_tests) + len(integration_tests)} arquivos de teste")
print("=" * 50)
# Out:
# 📊 ESTATÍSTICAS DE TESTES
# ==================================================
#
# ✅ Testes Unitários: 55 arquivos
#    • Features: 12 testes
#    • Processamento: 17 testes
#    • Treinamento: 15 testes
#    • Pipelines: 4 testes
#    • Utils: 3 testes
#
# 🔗 Testes de Integração: 7 arquivos
#
# 📦 TOTAL: 62 arquivos de teste
# ==================================================

# %% [markdown]
# ## 🔥 Executar Teste Customizado
#
# Use esta célula para executar comandos pytest personalizados.

# %% [markdown]
# ---
#
# ## 📚 Comandos Úteis Pytest
#
# ### Opções Comuns
# - `-v` : Verbose (mostra cada teste)
# - `-s` : Mostra prints durante testes
# - `-x` : Para no primeiro erro
# - `-k "palavra"` : Executa apenas testes com "palavra" no nome
# - `--tb=short` : Traceback curto
# - `--tb=long` : Traceback completo
# - `--tb=line` : Traceback de uma linha
# - `-q` : Modo quieto (apenas resumo)
# - `--maxfail=N` : Para após N falhas
# - `--lf` : Executa apenas testes que falharam na última execução
# - `--ff` : Executa testes que falharam primeiro
#
# ### Cobertura
# - `--cov=src` : Mede cobertura do código em src/
# - `--cov-report=html` : Gera relatório HTML
# - `--cov-report=term` : Mostra relatório no terminal
#
# ### Marcadores
# - `-m integration` : Executa apenas testes marcados como integração
# - `-m "not slow"` : Pula testes marcados como lentos
#
# ### Exemplos
# ```bash
# # Executar teste específico
# pytest tests/unit/features/test_normalizar.py::test_normalizar_standard
#
# # Executar testes que contém "pipeline" no nome
# pytest -k "pipeline"
#
# # Executar apenas testes que falharam
# pytest --lf
#
# # Executar com cobertura
# pytest --cov=src --cov-report=html
# ```

# %% [markdown]
# # 2. Testes de Qualidade de Código
